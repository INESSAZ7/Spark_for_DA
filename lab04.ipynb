# %%
import os
import sys
os.environ["PYSPARK_PYTHON"]='/opt/anaconda/envs/bd9/bin/python'
os.environ["SPARK_HOME"]='/usr/hdp/current/spark2-client'
os.environ["PYSPARK_SUBMIT_ARGS"]='--num-executors 5 --executor-memory 4g --executor-cores 1 --driver-memory 2g pyspark-shell'

spark_home = os.environ.get('SPARK_HOME', None)
if not spark_home:
    raise ValueError('SPARK_HOME environment variable is not set')

sys.path.insert(0, os.path.join(spark_home, 'python'))
sys.path.insert(0, os.path.join(spark_home, 'python/lib/py4j-0.10.7-src.zip'))
exec(open(os.path.join(spark_home, 'python/pyspark/shell.py')).read())
# Out:
# Welcome to
#       ____              __
#      / __/__  ___ _____/ /__
#     _\ \/ _ \/ _ `/ __/  '_/
#    /__ / .__/\_,_/_/ /_/\_\   version 2.4.7
#       /_/
#
# Using Python version 3.6.5 (default, Apr 29 2018 16:14:56)
# SparkSession available as 'spark'.

# %%
from pyspark import SparkConf
from pyspark.sql import SparkSession

conf = SparkConf()

spark = SparkSession.builder.config(conf=conf).getOrCreate()

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - hive</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://spark-master-4.newprolab.com:4050">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v2.4.7</code></dd>
#               <dt>Master</dt>
#                 <dd><code>yarn</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>pyspark-shell</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
import pyspark.sql.types as t
import pyspark.sql.functions as f
from pyspark.ml import Pipeline, PipelineModel
from pyspark.sql.types import StructType, StructField, DoubleType, StringType, IntegerType, FloatType, LongType, ArrayType
from pyspark.ml.feature import Tokenizer, HashingTF, StringIndexer, IndexToString
from pyspark.ml.classification import RandomForestClassifier

# %%
! hdfs dfs -ls /labs/slaba04/
# Out:
# Found 1 items
# -rw-r--r--   3 hdfs hdfs  655090069 2022-01-06 18:46 /labs/slaba04/gender_age_dataset.txt

# %%
! hdfs dfs -cat /labs/slaba04/gender_age_dataset.txt | head -n2
# Out:
# gender	age	uid	user_json
# F	18-24	d50192e5-c44e-4ae8-ae7a-7cfe67c8b777	{"visits": [{"url": "http://zebra-zoya.ru/200028-chehol-organayzer-dlja-macbook-11-grid-it.html?utm_campaign=397720794&utm_content=397729344&utm_medium=cpc&utm_source=begun", "timestamp": 1419688144068}, {"url": "http://news.yandex.ru/yandsearch?cl4url=chezasite.com/htc/htc-one-m9-delay-86327.html&lr=213&rpt=story", "timestamp": 1426666298001}, {"url": "http://www.sotovik.ru/news/240283-htc-one-m9-zaderzhivaetsja.html", "timestamp": 1426666298000}, {"url": "http://news.yandex.ru/yandsearch?cl4url=chezasite.com/htc/htc-one-m9-delay-86327.html&lr=213&rpt=story", "timestamp": 1426661722001}, {"url": "http://www.sotovik.ru/news/240283-htc-one-m9-zaderzhivaetsja.html", "timestamp": 1426661722000}]}
# cat: Unable to write to output stream.

# %%
path = '/labs/slaba04/gender_age_dataset.txt'

schema = StructType([
    StructField("gender", StringType()),
    StructField("age", StringType()),
    StructField("uid", StringType()),
    StructField("user_json", StringType()),
])

train_data = spark.read.csv(path, header=True, schema=schema, sep='\t')

# %%
train_data.show(2)
# Out:
# +------+-----+--------------------+--------------------+
# |gender|  age|                 uid|           user_json|
# +------+-----+--------------------+--------------------+
# |     F|18-24|d50192e5-c44e-4ae...|{"visits": [{"url...|
# |     M|25-34|d502331d-621e-472...|{"visits": [{"url...|
# +------+-----+--------------------+--------------------+
# only showing top 2 rows

# %%
train_data.printSchema()
# Out:
# root
#  |-- gender: string (nullable = true)
#  |-- age: string (nullable = true)
#  |-- uid: string (nullable = true)
#  |-- user_json: string (nullable = true)

# %%
visits_schema = StructType([
    StructField("visits", ArrayType(
        StructType([
            StructField("url", StringType(), True),
            StructField("timestamp", LongType(), True)
        ])
    ))    
])

# %%
# Фичи
df = train_data.withColumn("visits",f.from_json(train_data.user_json, schema=visits_schema))

# %%
df = df.withColumn('urls' , df['visits']['visits']['url'] )

# %%
df = df.withColumn("host", f.expr('transform(urls, x -> parse_url(x, "HOST" ))'))

# %%
df.show(5)
# Out:
# +------+-----+--------------------+--------------------+--------------------+--------------------+--------------------+
# |gender|  age|                 uid|           user_json|              visits|                urls|                host|
# +------+-----+--------------------+--------------------+--------------------+--------------------+--------------------+
# |     F|18-24|d50192e5-c44e-4ae...|{"visits": [{"url...|[[[http://zebra-z...|[http://zebra-zoy...|[zebra-zoya.ru, n...|
# |     M|25-34|d502331d-621e-472...|{"visits": [{"url...|[[[http://sweetra...|[http://sweetradi...|[sweetrading.ru, ...|
# |     F|25-34|d50237ea-747e-48a...|{"visits": [{"url...|[[[http://ru.orif...|[http://ru.orifla...|[ru.oriflame.com,...|
# |     F|25-34|d502f29f-d57a-46b...|{"visits": [{"url...|[[[http://transla...|[http://translate...|[translate-tattoo...|
# |     M| >=55|d503c3b2-a0c2-4f4...|{"visits": [{"url...|[[[https://mail.r...|[https://mail.ram...|[mail.rambler.ru,...|
# +------+-----+--------------------+--------------------+--------------------+--------------------+--------------------+
# only showing top 5 rows

# %%
df.groupby('age').count().show()
# Out:
# +-----+-----+
# |  age|count|
# +-----+-----+
# | >=55| 1679|
# |45-54| 4744|
# |    -| 5000|
# |35-44| 9360|
# |25-34|15457|
# |18-24| 4898|
# +-----+-----+

# %%
train = df.filter("age != '-'").filter("gender != '-'").drop('visits', 'urls', 'user_json')

# %%
train.show()
# Out:
# +------+-----+--------------------+--------------------+
# |gender|  age|                 uid|                host|
# +------+-----+--------------------+--------------------+
# |     F|18-24|d50192e5-c44e-4ae...|[zebra-zoya.ru, n...|
# |     M|25-34|d502331d-621e-472...|[sweetrading.ru, ...|
# |     F|25-34|d50237ea-747e-48a...|[ru.oriflame.com,...|
# |     F|25-34|d502f29f-d57a-46b...|[translate-tattoo...|
# |     M| >=55|d503c3b2-a0c2-4f4...|[mail.rambler.ru,...|
# |     F|25-34|d5090ddf-5648-487...|[cfire.mail.ru, p...|
# |     F|25-34|d50bcef8-16ff-4e8...|[www.msn.com, www...|
# |     F|18-24|d50e23dc-0cbd-488...|[www.gazprom.ru, ...|
# |     F|45-54|d50fdabb-4208-441...|[lifenews.ru, lif...|
# |     F|18-24|d511b480-23a6-482...|[www.google.ru, f...|
# |     F|25-34|d51294ed-1b95-4e4...|[muz4in.net, www....|
# |     F|25-34|d512e295-6a85-491...|[kosmetista.ru, k...|
# |     M|25-34|d51441ea-9dda-454...|[android.mobile-r...|
# |     F|25-34|d51822d4-105b-457...|[tsn.ua, cfts.org...|
# |     F|35-44|d5183db2-c8e5-413...|[www.jobinmoscow....|
# |     M|35-44|d51974e3-19c5-46d...|[www.abc-people.com]|
# |     M|25-34|d51cba2e-f666-46d...|[easygames.biz, e...|
# |     F|18-24|d51dd42c-3b36-4a6...|[www.ratanews.ru,...|
# |     F|35-44|d51fdc5e-8eae-4bb...|      [sam-zdrav.ru]|
# |     F| >=55|d522c18e-e38a-4b7...|[www.msn.com, www...|
# +------+-----+--------------------+--------------------+
# only showing top 20 rows

# %%
#pipeline
hashing_TF = HashingTF(inputCol="host", outputCol="features", numFeatures=10000)

indexer_age = StringIndexer(inputCol="age", outputCol="age_label").fit(train)
indexer_gender = StringIndexer(inputCol="gender", outputCol="gender_label").fit(train)

rfc_age = RandomForestClassifier(featuresCol="features", labelCol="age_label", predictionCol="age_label_pred", 
        rawPredictionCol="age_label_pred_raw", probabilityCol="age_label_pred_prob")

rfc_gender = RandomForestClassifier(featuresCol="features", labelCol="gender_label", predictionCol="gender_label_pred",
                rawPredictionCol="gender_label_raw_pred", probabilityCol="gender_label_prob")

# %%
pipeline = Pipeline(stages=[hashing_TF, 
                            indexer_age, 
                            indexer_gender, 
                            rfc_age, 
                            rfc_gender
                           ])

# %%
model = pipeline.fit(train)

# %%
sample1 = df.sample(True, 0.1, seed=0)

# %%
pred = model.transform(sample1)

# %%
pred.show(1)
# Out:
# +------+-----+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+---------+------------+--------------------+--------------------+--------------+---------------------+--------------------+-----------------+
# |gender|  age|                 uid|           user_json|              visits|                urls|                host|            features|age_label|gender_label|  age_label_pred_raw| age_label_pred_prob|age_label_pred|gender_label_raw_pred|   gender_label_prob|gender_label_pred|
# +------+-----+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+---------+------------+--------------------+--------------------+--------------+---------------------+--------------------+-----------------+
# |     F|25-34|d512e295-6a85-491...|{"visits": [{"url...|[[[http://kosmeti...|[http://kosmetist...|[kosmetista.ru, k...|(10000,[8726,9157...|      0.0|         1.0|[8.65915469854075...|[0.43295773492703...|           0.0| [10.2093829656465...|[0.51046914828232...|              0.0|
# +------+-----+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+---------+------------+--------------------+--------------------+--------------+---------------------+--------------------+-----------------+
# only showing top 1 row

# %%
from pyspark.ml.evaluation import BinaryClassificationEvaluator, MulticlassClassificationEvaluator

# %%
evaluator = MulticlassClassificationEvaluator(labelCol="age_label",
                                                  predictionCol="gender_label_pred", metricName="f1")

# %%
model.write().overwrite().save("/user/inessa.zabelina/labs/lab4_model")

# %%
# df = df.withColumn("event_properties", f.explode(f.array("visits.*")))
# df_exp = df.withColumn("visit", f.explode("event_properties"))
# df_exp.printSchema()
# df_exp = df_exp.withColumn('url', f.expr('parse_url(visit["url"], "HOST")'))
# df_exp = df_exp.withColumn('timestamp', df_exp.visit["timestamp"])
# df_new = df_exp.withColumn("new_json", 
#     f.struct(*[f.col('url').alias('url'), f.col('timestamp').alias('timestamp')])
# )
# df_new.printSchema()
# df = df_new.select('gender', 'age', 'uid', 'new_json')

# df_train = df.groupby('gender', 'age', 'uid').agg(f.collect_list("new_json").alias('url_timestamp'))

# %%
KAFKA_BOOTSTRAP_SERVER = 'spark-node-1.newprolab.com:6667'
KAFKA_INPUT_TOPIC = 'input_inessa.zabelina'
KAFKA_OUTPUT_TOPIC = 'inessa.zabelina'

# %%
input_kafka_params = {
    "kafka.bootstrap.servers": "spark-master-1.newprolab.com:6667",
    "subscribe": "input_inessa.zabelina",
    "startingOffsets": "earliest",
    "maxOffsetsPerTrigger": "5"
}

# %%
write_kafka_params = {
    "kafka.bootstrap.servers": "spark-master-1.newprolab.com:6667",
    "topic": "inessa.zabelina"
}

# %%
sdf = spark.readStream.format("kafka").options(**input_kafka_params).load()

# %%
event_type = StructType([
    StructField("uid", StringType(), True),
    StructField("visits", StringType(), True)
])

# %%
visit_type = ArrayType(
    StructType([
        StructField("url", StringType(), True),
        StructField("timestamp", LongType(), True)
    ])
)

# %%
def foreachBatchFunction(batch_df, batch_id) :
    
    parced_data = batch_df\
        .select(col("value").cast("string").alias("value"))\
        .select(from_json(col("value"), event_type).alias("data"))\
        .select("data.*")\
        .select("uid", from_json(col("visits"), visit_type).alias("visits"))
    parced_data.show(1)
    
    proc_df = parced_data\
        .withColumn("visit", explode("visits").alias("visits"))\
        .withColumn("host", regexp_replace(expr("parse_url(visit.url), 'HOST'").alias("host")), "^www.", "")\
        .filter("age != '-'").filter("gender != '-'").drop("visits", "visit")\
        .groupBy("uid")\
        .agg(collect_list("host").alias("hosts"))
    
    proc_df.show(1)
    
    predict_df = lab_model\
        .transform(proc_df)\
        .select("uid", "PredictedGender", "PredictedAge")\
        .withColumnRenamed("PredictedAge", "age")\
        .withColumnRenamed("PredictedGender", "gender")
    
    predict_df.show(1)
    
    predict_df = predict_df.select(to_json(struct(*predict_df.columns)).alias("value"))

    return predict_df

# %%
lab_model = PipelineModel.load("/user/inessa.zabelina/labs/lab4_model")

# %%
sink = sdf.writeStream\
    .foreachBatch(foreachBatchFunction)\
    .format('kafka')\
    .option("kafka.bootstrap.servers", KAFKA_BOOTSTRAP_SERVER)\
    .option("topic", KAFKA_OUTPUT_TOPIC)\
    .option("checkpointLocation", 'streaming/chk/chk_kafka')\
    .outputMode("append")

# %%
sq = sink.start()

# %%
sq.isActive
# Out:
# True

# %%
sq.status
# Out:
# {'message': 'Writing offsets to log',
#  'isDataAvailable': True,
#  'isTriggerActive': True}

# %%
sq.recentProgress
# Out:
# [{'id': 'ba1dd17e-31f7-4106-b520-f301924999af',
#   'runId': 'cfebd165-bbbf-4244-8239-632332653baa',
#   'name': None,
#   'timestamp': '2023-02-27T19:34:56.382Z',
#   'batchId': 4034,
#   'numInputRows': 5,
#   'inputRowsPerSecond': 48.07692307692308,
#   'processedRowsPerSecond': 50.505050505050505,
#   'durationMs': {'addBatch': 31,
#    'getBatch': 0,
#    'getEndOffset': 1,
#    'queryPlanning': 7,
#    'setOffsetRange': 1,
#    'triggerExecution': 99,
#    'walCommit': 31},
#   'stateOperators': [],
#   'sources': [{'description': 'KafkaV2[Subscribe[input_inessa.zabelina]]',
#     'startOffset': {'input_inessa.zabelina': {'0': 25165}},
#     'endOffset': {'input_inessa.zabelina': {'0': 25170}},
#     'numInputRows': 5,
#     'inputRowsPerSecond': 48.07692307692308,
#     'processedRowsPerSecond': 50.505050505050505}],
#   'sink': {'description': 'org.apache.spark.sql.kafka010.KafkaSourceProvider@62f8529a'}},
#  {'id': 'ba1dd17e-31f7-4106-b520-f301924999af',
#   'runId': 'cfebd165-bbbf-4244-8239-632332653baa',
#   'name': None,
#   'timestamp': '2023-02-27T19:34:56.482Z',
#   'batchId': 4035,
#   'numInputRows': 5,
#   'inputRowsPerSecond': 50.0,
#   'processedRowsPerSecond': 47.16981132075472,
#   'durationMs': {'addBatch': 36,
#    'getBatch': 1,
#    'getEndOffset': 0,
#    'queryPlanning': 8,
#    'setOffsetRange': 2,
#    'triggerExecution': 106,
#    'walCommit': 36},
#   'stateOperators': [],
#   'sources': [{'description': 'KafkaV2[Subscribe[input_inessa.zabelina]]',
#     'startOffset': {'input_inessa.zabelina': {'0': 25170}},
#     'endOffset': {'input_inessa.zabelina': {'0': 25175}},
#     'numInputRows': 5,
#     'inputRowsPerSecond': 50.0,
#     'processedRowsPerSecond': 47.16981132075472}],
#   'sink': {'description': 'org.apache.spark.sql.kafka010.KafkaSourceProvider@62f8529a'}},
#  {'id': 'ba1dd17e-31f7-4106-b520-f301924999af',
#   'runId': 'cfebd165-bbbf-4244-8239-632332653baa',
#   'name': None,
#   'timestamp': '2023-02-27T19:34:56.589Z',
#   'batchId': 4036,
#   'numInputRows': 5,
#   'inputRowsPerSecond': 46.728971962616825,
#   'processedRowsPerSecond': 50.505050505050505,
#   'durationMs': {'addBatch': 35,
#    'getBatch': 0,
#    'getEndOffset': 0,
#    'queryPlanning': 7,
#    'setOffsetRange': 2,
#    'triggerExecution': 99,
#    'walCommit': 31},
#   'stateOperators': [],
#   'sources': [{'description': 'KafkaV2[Subscribe[input_inessa.zabelina]]',
#     'startOffset': {'input_inessa.zabelina': {'0': 25175}},
#     'endOffset': {'input_inessa.zabelina': {'0': 25180}},
#     'numInputRows': 5,
#     'inputRowsPerSecond': 46.728971962616825,
#     'processedRowsPerSecond': 50.505050505050505}],
#   'sink': {'description': 'org.apache.spark.sql.kafka010.KafkaSourceProvider@62f8529a'}},
#  {'id': 'ba1dd17e-31f7-4106-b520-f301924999af',
#   'runId': 'cfebd165-bbbf-4244-8239-632332653baa',
#   'name': None,
#   'timestamp': '2023-02-27T19:34:56.689Z',
#   'batchId': 4037,
#   'numInputRows': 5,
#   'inputRowsPerSecond': 50.0,
#   'processedRowsPerSecond': 40.32258064516129,
#   'durationMs': {'addBatch': 60,
#    'getBatch': 1,
#    'getEndOffset': 1,
#    'queryPlanning': 8,
#    'setOffsetRange': 1,
#    'triggerExecution': 123,
#    'walCommit': 30},
#   'stateOperators': [],
#   'sources': [{'description': 'KafkaV2[Subscribe[input_inessa.zabelina]]',
#     'startOffset': {'input_inessa.zabelina': {'0': 25180}},
#     'endOffset': {'input_inessa.zabelina': {'0': 25185}},
#     'numInputRows': 5,
#     'inputRowsPerSecond': 50.0,
#     'processedRowsPerSecond': 40.32258064516129}],
#   'sink': {'description': 'org.apache.spark.sql.kafka010.KafkaSourceProvider@62f8529a'}},
#  {'id': 'ba1dd17e-31f7-4106-b520-f301924999af',
#   'runId': 'cfebd165-bbbf-4244-8239-632332653baa',
#   'name': None,
#   'timestamp': '2023-02-27T19:34:56.813Z',
#   'batchId': 4038,
#   'numInputRows': 5,
#   'inputRowsPerSecond': 40.32258064516129,
#   'processedRowsPerSecond': 40.32258064516129,
#   'durationMs': {'addBatch': 53,
#    'getBatch': 0,
#    'getEndOffset': 0,
#    'queryPlanning': 8,
#    'setOffsetRange': 2,
#    'triggerExecution': 124,
#    'walCommit': 36},
#   'stateOperators': [],
#   'sources': [{'description': 'KafkaV2[Subscribe[input_inessa.zabelina]]',
#     'startOffset': {'input_inessa.zabelina': {'0': 25185}},
#     'endOffset': {'input_inessa.zabelina': {'0': 25190}},
#     'numInputRows': 5,
#     'inputRowsPerSecond': 40.32258064516129,
#     'processedRowsPerSecond': 40.32258064516129}],
#   'sink': {'description': 'org.apache.spark.sql.kafka010.KafkaSourceProvider@62f8529a'}},
#  {'id': 'ba1dd17e-31f7-4106-b520-f301924999af',
#   'runId': 'cfebd165-bbbf-4244-8239-632332653baa',
#   'name': None,
#   'timestamp': '2023-02-27T19:34:56.937Z',
#   'batchId': 4039,
#   'numInputRows': 5,
#   'inputRowsPerSecond': 40.32258064516129,
#   'processedRowsPerSecond': 51.0204081632653,
#   'durationMs': {'addBatch': 32,
#    'getBatch': 0,
#    'getEndOffset': 0,
#    'queryPlanning': 7,
#    'setOffsetRange': 2,
#    'triggerExecution': 98,
#    'walCommit': 31},
#   'stateOperators': [],
#   'sources': [{'description': 'KafkaV2[Subscribe[input_inessa.zabelina]]',
#     'startOffset': {'input_inessa.zabelina': {'0': 25190}},
#     'endOffset': {'input_inessa.zabelina': {'0': 25195}},
#     'numInputRows': 5,
#     'inputRowsPerSecond': 40.32258064516129,
#     'processedRowsPerSecond': 51.0204081632653}],
#   'sink': {'description': 'org.apache.spark.sql.kafka010.KafkaSourceProvider@62f8529a'}},
#  {'id': 'ba1dd17e-31f7-4106-b520-f301924999af',
#   'runId': 'cfebd165-bbbf-4244-8239-632332653baa',
#   'name': None,
#   'timestamp': '2023-02-27T19:34:57.038Z',
#   'batchId': 4040,
#   'numInputRows': 5,
#   'inputRowsPerSecond': 49.5049504950495,
#   'processedRowsPerSecond': 48.07692307692308,
#   'durationMs': {'addBatch': 34,
#    'getBatch': 1,
#    'getEndOffset': 0,
#    'queryPlanning': 8,
#    'setOffsetRange': 1,
#    'triggerExecution': 104,
#    'walCommit': 41},
#   'stateOperators': [],
#   'sources': [{'description': 'KafkaV2[Subscribe[input_inessa.zabelina]]',
#     'startOffset': {'input_inessa.zabelina': {'0': 25195}},
#     'endOffset': {'input_inessa.zabelina': {'0': 25200}},
#     'numInputRows': 5,
#     'inputRowsPerSecond': 49.5049504950495,
#     'processedRowsPerSecond': 48.07692307692308}],
#   'sink': {'description': 'org.apache.spark.sql.kafka010.KafkaSourceProvider@62f8529a'}},
#  {'id': 'ba1dd17e-31f7-4106-b520-f301924999af',
#   'runId': 'cfebd165-bbbf-4244-8239-632332653baa',
#   'name': None,
#   'timestamp': '2023-02-27T19:34:57.143Z',
#   'batchId': 4041,
#   'numInputRows': 5,
#   'inputRowsPerSecond': 47.61904761904762,
#   'processedRowsPerSecond': 49.5049504950495,
#   'durationMs': {'addBatch': 33,
#    'getBatch': 0,
#    'getEndOffset': 0,
#    'queryPlanning': 12,
#    'setOffsetRange': 2,
#    'triggerExecution': 101,
#    'walCommit': 31},
#   'stateOperators': [],
#   'sources': [{'description': 'KafkaV2[Subscribe[input_inessa.zabelina]]',
#     'startOffset': {'input_inessa.zabelina': {'0': 25200}},
#     'endOffset': {'input_inessa.zabelina': {'0': 25205}},
#     'numInputRows': 5,
#     'inputRowsPerSecond': 47.61904761904762,
#     'processedRowsPerSecond': 49.5049504950495}],
#   'sink': {'description': 'org.apache.spark.sql.kafka010.KafkaSourceProvider@62f8529a'}},
#  {'id': 'ba1dd17e-31f7-4106-b520-f301924999af',
#   'runId': 'cfebd165-bbbf-4244-8239-632332653baa',
#   'name': None,
#   'timestamp': '2023-02-27T19:34:57.245Z',
#   'batchId': 4042,
#   'numInputRows': 5,
#   'inputRowsPerSecond': 49.01960784313726,
#   'processedRowsPerSecond': 50.505050505050505,
#   'durationMs': {'addBatch': 31,
#    'getBatch': 1,
#    'getEndOffset': 0,
#    'queryPlanning': 7,
#    'setOffsetRange': 2,
#    'triggerExecution': 99,
#    'walCommit': 34},
#   'stateOperators': [],
#   'sources': [{'description': 'KafkaV2[Subscribe[input_inessa.zabelina]]',
#     'startOffset': {'input_inessa.zabelina': {'0': 25205}},
#     'endOffset': {'input_inessa.zabelina': {'0': 25210}},
#     'numInputRows': 5,
#     'inputRowsPerSecond': 49.01960784313726,
#     'processedRowsPerSecond': 50.505050505050505}],
#   'sink': {'description': 'org.apache.spark.sql.kafka010.KafkaSourceProvider@62f8529a'}},
#  {'id': 'ba1dd17e-31f7-4106-b520-f301924999af',
#   'runId': 'cfebd165-bbbf-4244-8239-632332653baa',
#   'name': None,
#   'timestamp': '2023-02-27T19:34:57.344Z',
#   'batchId': 4043,
#   'numInputRows': 5,
#   'inputRowsPerSecond': 50.505050505050505,
#   'processedRowsPerSecond': 45.87155963302752,
#   'durationMs': {'addBatch': 36,
#    'getBatch': 0,
#    'getEndOffset': 0,
#    'queryPlanning': 7,
#    'setOffsetRange': 3,
#    'triggerExecution': 109,
#    'walCommit': 38},
#   'stateOperators': [],
#   'sources': [{'description': 'KafkaV2[Subscribe[input_inessa.zabelina]]',
#     'startOffset': {'input_inessa.zabelina': {'0': 25210}},
#     'endOffset': {'input_inessa.zabelina': {'0': 25215}},
#     'numInputRows': 5,
#     'inputRowsPerSecond': 50.505050505050505,
#     'processedRowsPerSecond': 45.87155963302752}],
#   'sink': {'description': 'org.apache.spark.sql.kafka010.KafkaSourceProvider@62f8529a'}},
#  {'id': 'ba1dd17e-31f7-4106-b520-f301924999af',
#   'runId': 'cfebd165-bbbf-4244-8239-632332653baa',
#   'name': None,
#   'timestamp': '2023-02-27T19:34:57.453Z',
#   'batchId': 4044,
#   'numInputRows': 5,
#   'inputRowsPerSecond': 45.87155963302752,
#   'processedRowsPerSecond': 52.63157894736842,
#   'durationMs': {'addBatch': 31,
#    'getBatch': 0,
#    'getEndOffset': 0,
#    'queryPlanning': 8,
#    'setOffsetRange': 2,
#    'triggerExecution': 95,
#    'walCommit': 30},
#   'stateOperators': [],
#   'sources': [{'description': 'KafkaV2[Subscribe[input_inessa.zabelina]]',
#     'startOffset': {'input_inessa.zabelina': {'0': 25215}},
#     'endOffset': {'input_inessa.zabelina': {'0': 25220}},
#     'numInputRows': 5,
#     'inputRowsPerSecond': 45.87155963302752,
#     'processedRowsPerSecond': 52.63157894736842}],
#   'sink': {'description': 'org.apache.spark.sql.kafka010.KafkaSourceProvider@62f8529a'}},
#  {'id': 'ba1dd17e-31f7-4106-b520-f301924999af',
#   'runId': 'cfebd165-bbbf-4244-8239-632332653baa',
#   'name': None,
#   'timestamp': '2023-02-27T19:34:57.548Z',
#   'batchId': 4045,
#   'numInputRows': 5,
#   'inputRowsPerSecond': 52.63157894736842,
#   'processedRowsPerSecond': 50.505050505050505,
#   'durationMs': {'addBatch': 35,
#    'getBatch': 0,
#    'getEndOffset': 0,
#    'queryPlanning': 9,
#    'setOffsetRange': 2,
#    'triggerExecution': 99,
#    'walCommit': 31},
#   'stateOperators': [],
#   'sources': [{'description': 'KafkaV2[Subscribe[input_inessa.zabelina]]',
#     'startOffset': {'input_inessa.zabelina': {'0': 25220}},
#     'endOffset': {'input_inessa.zabelina': {'0': 25225}},
#     'numInputRows': 5,
#     'inputRowsPerSecond': 52.63157894736842,
#     'processedRowsPerSecond': 50.505050505050505}],
#   'sink': {'description': 'org.apache.spark.sql.kafka010.KafkaSourceProvider@62f8529a'}},
#  {'id': 'ba1dd17e-31f7-4106-b520-f301924999af',
#   'runId': 'cfebd165-bbbf-4244-8239-632332653baa',
#   'name': None,
#   'timestamp': '2023-02-27T19:34:57.648Z',
#   'batchId': 4046,
#   'numInputRows': 5,
#   'inputRowsPerSecond': 50.0,
#   'processedRowsPerSecond': 46.2962962962963,
#   'durationMs': {'addBatch': 36,
#    'getBatch': 1,
#    'getEndOffset': 0,
#    'queryPlanning': 7,
#    'setOffsetRange': 2,
#    'triggerExecution': 108,
#    'walCommit': 29},
#   'stateOperators': [],
#   'sources': [{'description': 'KafkaV2[Subscribe[input_inessa.zabelina]]',
#     'startOffset': {'input_inessa.zabelina': {'0': 25225}},
#     'endOffset': {'input_inessa.zabelina': {'0': 25230}},
#     'numInputRows': 5,
#     'inputRowsPerSecond': 50.0,
#     'processedRowsPerSecond': 46.2962962962963}],
#   'sink': {'description': 'org.apache.spark.sql.kafka010.KafkaSourceProvider@62f8529a'}},
#  {'id': 'ba1dd17e-31f7-4106-b520-f301924999af',
#   'runId': 'cfebd165-bbbf-4244-8239-632332653baa',
#   'name': None,
#   'timestamp': '2023-02-27T19:34:57.756Z',
#   'batchId': 4047,
#   'numInputRows': 5,
#   'inputRowsPerSecond': 46.2962962962963,
#   'processedRowsPerSecond': 47.61904761904762,
#   'durationMs': {'addBatch': 41,
#    'getBatch': 0,
#    'getEndOffset': 0,
#    'queryPlanning': 8,
#    'setOffsetRange': 2,
#    'triggerExecution': 105,
#    'walCommit': 30},
#   'stateOperators': [],
#   'sources': [{'description': 'KafkaV2[Subscribe[input_inessa.zabelina]]',
#     'startOffset': {'input_inessa.zabelina': {'0': 25230}},
#     'endOffset': {'input_inessa.zabelina': {'0': 25235}},
#     'numInputRows': 5,
#     'inputRowsPerSecond': 46.2962962962963,
#     'processedRowsPerSecond': 47.61904761904762}],
#   'sink': {'description': 'org.apache.spark.sql.kafka010.KafkaSourceProvider@62f8529a'}},
#  {'id': 'ba1dd17e-31f7-4106-b520-f301924999af',
#   'runId': 'cfebd165-bbbf-4244-8239-632332653baa',
#   'name': None,
#   'timestamp': '2023-02-27T19:34:57.861Z',
#   'batchId': 4048,
#   'numInputRows': 5,
#   'inputRowsPerSecond': 47.61904761904762,
#   'processedRowsPerSecond': 41.32231404958678,
#   'durationMs': {'addBatch': 55,
#    'getBatch': 0,
#    'getEndOffset': 0,
#    'queryPlanning': 8,
#    'setOffsetRange': 2,
#    'triggerExecution': 121,
#    'walCommit': 31},
#   'stateOperators': [],
#   'sources': [{'description': 'KafkaV2[Subscribe[input_inessa.zabelina]]',
#     'startOffset': {'input_inessa.zabelina': {'0': 25235}},
#     'endOffset': {'input_inessa.zabelina': {'0': 25240}},
#     'numInputRows': 5,
#     'inputRowsPerSecond': 47.61904761904762,
#     'processedRowsPerSecond': 41.32231404958678}],
#   'sink': {'description': 'org.apache.spark.sql.kafka010.KafkaSourceProvider@62f8529a'}},
#  {'id': 'ba1dd17e-31f7-4106-b520-f301924999af',
#   'runId': 'cfebd165-bbbf-4244-8239-632332653baa',
#   'name': None,
#   'timestamp': '2023-02-27T19:34:57.982Z',
#   'batchId': 4049,
#   'numInputRows': 5,
#   'inputRowsPerSecond': 41.32231404958678,
#   'processedRowsPerSecond': 55.55555555555556,
#   'durationMs': {'addBatch': 31,
#    'getBatch': 0,
#    'getEndOffset': 0,
#    'queryPlanning': 7,
#    'setOffsetRange': 2,
#    'triggerExecution': 90,
#    'walCommit': 28},
#   'stateOperators': [],
#   'sources': [{'description': 'KafkaV2[Subscribe[input_inessa.zabelina]]',
#     'startOffset': {'input_inessa.zabelina': {'0': 25240}},
#     'endOffset': {'input_inessa.zabelina': {'0': 25245}},
#     'numInputRows': 5,
#     'inputRowsPerSecond': 41.32231404958678,
#     'processedRowsPerSecond': 55.55555555555556}],
#   'sink': {'description': 'org.apache.spark.sql.kafka010.KafkaSourceProvider@62f8529a'}},
#  {'id': 'ba1dd17e-31f7-4106-b520-f301924999af',
#   'runId': 'cfebd165-bbbf-4244-8239-632332653baa',
#   'name': None,
#   'timestamp': '2023-02-27T19:34:58.073Z',
#   'batchId': 4050,
#   'numInputRows': 5,
#   'inputRowsPerSecond': 54.94505494505495,
#   'processedRowsPerSecond': 57.4712643678161,
#   'durationMs': {'addBatch': 28,
#    'getBatch': 1,
#    'getEndOffset': 0,
#    'queryPlanning': 7,
#    'setOffsetRange': 2,
#    'triggerExecution': 87,
#    'walCommit': 30},
#   'stateOperators': [],
#   'sources': [{'description': 'KafkaV2[Subscribe[input_inessa.zabelina]]',
#     'startOffset': {'input_inessa.zabelina': {'0': 25245}},
#     'endOffset': {'input_inessa.zabelina': {'0': 25250}},
#     'numInputRows': 5,
#     'inputRowsPerSecond': 54.94505494505495,
#     'processedRowsPerSecond': 57.4712643678161}],
#   'sink': {'description': 'org.apache.spark.sql.kafka010.KafkaSourceProvider@62f8529a'}},
#  {'id': 'ba1dd17e-31f7-4106-b520-f301924999af',
#   'runId': 'cfebd165-bbbf-4244-8239-632332653baa',
#   'name': None,
#   'timestamp': '2023-02-27T19:34:58.160Z',
#   'batchId': 4051,
#   'numInputRows': 5,
#   'inputRowsPerSecond': 57.4712643678161,
#   'processedRowsPerSecond': 57.4712643678161,
#   'durationMs': {'addBatch': 26,
#    'getBatch': 0,
#    'getEndOffset': 0,
#    'queryPlanning': 7,
#    'setOffsetRange': 2,
#    'triggerExecution': 87,
#    'walCommit': 30},
#   'stateOperators': [],
#   'sources': [{'description': 'KafkaV2[Subscribe[input_inessa.zabelina]]',
#     'startOffset': {'input_inessa.zabelina': {'0': 25250}},
#     'endOffset': {'input_inessa.zabelina': {'0': 25255}},
#     'numInputRows': 5,
#     'inputRowsPerSecond': 57.4712643678161,
#     'processedRowsPerSecond': 57.4712643678161}],
#   'sink': {'description': 'org.apache.spark.sql.kafka010.KafkaSourceProvider@62f8529a'}},
#  {'id': 'ba1dd17e-31f7-4106-b520-f301924999af',
#   'runId': 'cfebd165-bbbf-4244-8239-632332653baa',
#   'name': None,
#   'timestamp': '2023-02-27T19:34:58.248Z',
#   'batchId': 4052,
#   'numInputRows': 5,
#   'inputRowsPerSecond': 56.81818181818182,
#   'processedRowsPerSecond': 53.191489361702125,
#   'durationMs': {'addBatch': 29,
#    'getBatch': 1,
#    'getEndOffset': 0,
#    'queryPlanning': 8,
#    'setOffsetRange': 2,
#    'triggerExecution': 94,
#    'walCommit': 33},
#   'stateOperators': [],
#   'sources': [{'description': 'KafkaV2[Subscribe[input_inessa.zabelina]]',
#     'startOffset': {'input_inessa.zabelina': {'0': 25255}},
#     'endOffset': {'input_inessa.zabelina': {'0': 25260}},
#     'numInputRows': 5,
#     'inputRowsPerSecond': 56.81818181818182,
#     'processedRowsPerSecond': 53.191489361702125}],
#   'sink': {'description': 'org.apache.spark.sql.kafka010.KafkaSourceProvider@62f8529a'}},
#  {'id': 'ba1dd17e-31f7-4106-b520-f301924999af',
#   'runId': 'cfebd165-bbbf-4244-8239-632332653baa',
#   'name': None,
#   'timestamp': '2023-02-27T19:34:58.342Z',
#   'batchId': 4053,
#   'numInputRows': 5,
#   'inputRowsPerSecond': 53.191489361702125,
#   'processedRowsPerSecond': 50.505050505050505,
#   'durationMs': {'addBatch': 33,
#    'getBatch': 0,
#    'getEndOffset': 0,
#    'queryPlanning': 10,
#    'setOffsetRange': 2,
#    'triggerExecution': 99,
#    'walCommit': 31},
#   'stateOperators': [],
#   'sources': [{'description': 'KafkaV2[Subscribe[input_inessa.zabelina]]',
#     'startOffset': {'input_inessa.zabelina': {'0': 25260}},
#     'endOffset': {'input_inessa.zabelina': {'0': 25265}},
#     'numInputRows': 5,
#     'inputRowsPerSecond': 53.191489361702125,
#     'processedRowsPerSecond': 50.505050505050505}],
#   'sink': {'description': 'org.apache.spark.sql.kafka010.KafkaSourceProvider@62f8529a'}},
#  {'id': 'ba1dd17e-31f7-4106-b520-f301924999af',
#   'runId': 'cfebd165-bbbf-4244-8239-632332653baa',
#   'name': None,
#   'timestamp': '2023-02-27T19:34:58.441Z',
#   'batchId': 4054,
#   'numInputRows': 5,
#   'inputRowsPerSecond': 50.505050505050505,
#   'processedRowsPerSecond': 52.63157894736842,
#   'durationMs': {'addBatch': 29,
#    'getBatch': 0,
#    'getEndOffset': 0,
#    'queryPlanning': 8,
#    'setOffsetRange': 2,
#    'triggerExecution': 95,
#    'walCommit': 32},
#   'stateOperators': [],
#   'sources': [{'description': 'KafkaV2[Subscribe[input_inessa.zabelina]]',
#     'startOffset': {'input_inessa.zabelina': {'0': 25265}},
#     'endOffset': {'input_inessa.zabelina': {'0': 25270}},
#     'numInputRows': 5,
#     'inputRowsPerSecond': 50.505050505050505,
#     'processedRowsPerSecond': 52.63157894736842}],
#   'sink': {'description': 'org.apache.spark.sql.kafka010.KafkaSourceProvider@62f8529a'}},
#  {'id': 'ba1dd17e-31f7-4106-b520-f301924999af',
#   'runId': 'cfebd165-bbbf-4244-8239-632332653baa',
#   'name': None,
#   'timestamp': '2023-02-27T19:34:58.536Z',
#   'batchId': 4055,
#   'numInputRows': 5,
#   'inputRowsPerSecond': 52.63157894736842,
#   'processedRowsPerSecond': 51.54639175257732,
#   'durationMs': {'addBatch': 31,
#    'getBatch': 0,
#    'getEndOffset': 0,
#    'queryPlanning': 8,
#    'setOffsetRange': 2,
#    'triggerExecution': 97,
#    'walCommit': 32},
#   'stateOperators': [],
#   'sources': [{'description': 'KafkaV2[Subscribe[input_inessa.zabelina]]',
#     'startOffset': {'input_inessa.zabelina': {'0': 25270}},
#     'endOffset': {'input_inessa.zabelina': {'0': 25275}},
#     'numInputRows': 5,
#     'inputRowsPerSecond': 52.63157894736842,
#     'processedRowsPerSecond': 51.54639175257732}],
#   'sink': {'description': 'org.apache.spark.sql.kafka010.KafkaSourceProvider@62f8529a'}},
#  {'id': 'ba1dd17e-31f7-4106-b520-f301924999af',
#   'runId': 'cfebd165-bbbf-4244-8239-632332653baa',
#   'name': None,
#   'timestamp': '2023-02-27T19:34:58.633Z',
#   'batchId': 4056,
#   'numInputRows': 5,
#   'inputRowsPerSecond': 51.54639175257732,
#   'processedRowsPerSecond': 52.63157894736842,
#   'durationMs': {'addBatch': 31,
#    'getBatch': 0,
#    'getEndOffset': 0,
#    'queryPlanning': 8,
#    'setOffsetRange': 3,
#    'triggerExecution': 95,
#    'walCommit': 32},
#   'stateOperators': [],
#   'sources': [{'description': 'KafkaV2[Subscribe[input_inessa.zabelina]]',
#     'startOffset': {'input_inessa.zabelina': {'0': 25275}},
#     'endOffset': {'input_inessa.zabelina': {'0': 25280}},
#     'numInputRows': 5,
#     'inputRowsPerSecond': 51.54639175257732,
#     'processedRowsPerSecond': 52.63157894736842}],
#   'sink': {'description': 'org.apache.spark.sql.kafka010.KafkaSourceProvider@62f8529a'}},
#  {'id': 'ba1dd17e-31f7-4106-b520-f301924999af',
#   'runId': 'cfebd165-bbbf-4244-8239-632332653baa',
#   'name': None,
#   'timestamp': '2023-02-27T19:34:58.729Z',
#   'batchId': 4057,
#   'numInputRows': 5,
#   'inputRowsPerSecond': 52.083333333333336,
#   'processedRowsPerSecond': 43.47826086956522,
#   'durationMs': {'addBatch': 34,
#    'getBatch': 2,
#    'getEndOffset': 0,
#    'queryPlanning': 8,
#    'setOffsetRange': 2,
#    'triggerExecution': 115,
#    'walCommit': 46},
#   'stateOperators': [],
#   'sources': [{'description': 'KafkaV2[Subscribe[input_inessa.zabelina]]',
#     'startOffset': {'input_inessa.zabelina': {'0': 25280}},
#     'endOffset': {'input_inessa.zabelina': {'0': 25285}},
#     'numInputRows': 5,
#     'inputRowsPerSecond': 52.083333333333336,
#     'processedRowsPerSecond': 43.47826086956522}],
#   'sink': {'description': 'org.apache.spark.sql.kafka010.KafkaSourceProvider@62f8529a'}},
#  {'id': 'ba1dd17e-31f7-4106-b520-f301924999af',
#   'runId': 'cfebd165-bbbf-4244-8239-632332653baa',
#   'name': None,
#   'timestamp': '2023-02-27T19:34:58.844Z',
#   'batchId': 4058,
#   'numInputRows': 5,
#   'inputRowsPerSecond': 43.47826086956522,
#   'processedRowsPerSecond': 53.191489361702125,
#   'durationMs': {'addBatch': 29,
#    'getBatch': 0,
#    'getEndOffset': 0,
#    'queryPlanning': 9,
#    'setOffsetRange': 2,
#    'triggerExecution': 94,
#    'walCommit': 31},
#   'stateOperators': [],
#   'sources': [{'description': 'KafkaV2[Subscribe[input_inessa.zabelina]]',
#     'startOffset': {'input_inessa.zabelina': {'0': 25285}},
#     'endOffset': {'input_inessa.zabelina': {'0': 25290}},
#     'numInputRows': 5,
#     'inputRowsPerSecond': 43.47826086956522,
#     'processedRowsPerSecond': 53.191489361702125}],
#   'sink': {'description': 'org.apache.spark.sql.kafka010.KafkaSourceProvider@62f8529a'}},
#  {'id': 'ba1dd17e-31f7-4106-b520-f301924999af',
#   'runId': 'cfebd165-bbbf-4244-8239-632332653baa',
#   'name': None,
#   'timestamp': '2023-02-27T19:34:58.938Z',
#   'batchId': 4059,
#   'numInputRows': 5,
#   'inputRowsPerSecond': 53.191489361702125,
#   'processedRowsPerSecond': 49.01960784313726,
#   'durationMs': {'addBatch': 34,
#    'getBatch': 1,
#    'getEndOffset': 0,
#    'queryPlanning': 9,
#    'setOffsetRange': 2,
#    'triggerExecution': 102,
#    'walCommit': 32},
#   'stateOperators': [],
#   'sources': [{'description': 'KafkaV2[Subscribe[input_inessa.zabelina]]',
#     'startOffset': {'input_inessa.zabelina': {'0': 25290}},
#     'endOffset': {'input_inessa.zabelina': {'0': 25295}},
#     'numInputRows': 5,
#     'inputRowsPerSecond': 53.191489361702125,
#     'processedRowsPerSecond': 49.01960784313726}],
#   'sink': {'description': 'org.apache.spark.sql.kafka010.KafkaSourceProvider@62f8529a'}},
#  {'id': 'ba1dd17e-31f7-4106-b520-f301924999af',
#   'runId': 'cfebd165-bbbf-4244-8239-632332653baa',
#   'name': None,
#   'timestamp': '2023-02-27T19:34:59.040Z',
#   'batchId': 4060,
#   'numInputRows': 5,
#   'inputRowsPerSecond': 49.01960784313726,
#   'processedRowsPerSecond': 43.103448275862064,
#   'durationMs': {'addBatch': 46,
#    'getBatch': 0,
#    'getEndOffset': 0,
#    'queryPlanning': 7,
#    'setOffsetRange': 2,
#    'triggerExecution': 115,
#    'walCommit': 38},
#   'stateOperators': [],
#   'sources': [{'description': 'KafkaV2[Subscribe[input_inessa.zabelina]]',
#     'startOffset': {'input_inessa.zabelina': {'0': 25295}},
#     'endOffset': {'input_inessa.zabelina': {'0': 25300}},
#     'numInputRows': 5,
#     'inputRowsPerSecond': 49.01960784313726,
#     'processedRowsPerSecond': 43.103448275862064}],
#   'sink': {'description': 'org.apache.spark.sql.kafka010.KafkaSourceProvider@62f8529a'}},
#  {'id': 'ba1dd17e-31f7-4106-b520-f301924999af',
#   'runId': 'cfebd165-bbbf-4244-8239-632332653baa',
#   'name': None,
#   'timestamp': '2023-02-27T19:34:59.156Z',
#   'batchId': 4061,
#   'numInputRows': 5,
#   'inputRowsPerSecond': 43.103448275862064,
#   'processedRowsPerSecond': 35.97122302158273,
#   'durationMs': {'addBatch': 32,
#    'getBatch': 0,
#    'getEndOffset': 0,
#    'queryPlanning': 47,
#    'setOffsetRange': 2,
#    'triggerExecution': 139,
#    'walCommit': 34},
#   'stateOperators': [],
#   'sources': [{'description': 'KafkaV2[Subscribe[input_inessa.zabelina]]',
#     'startOffset': {'input_inessa.zabelina': {'0': 25300}},
#     'endOffset': {'input_inessa.zabelina': {'0': 25305}},
#     'numInputRows': 5,
#     'inputRowsPerSecond': 43.103448275862064,
#     'processedRowsPerSecond': 35.97122302158273}],
#   'sink': {'description': 'org.apache.spark.sql.kafka010.KafkaSourceProvider@62f8529a'}},
#  {'id': 'ba1dd17e-31f7-4106-b520-f301924999af',
#   'runId': 'cfebd165-bbbf-4244-8239-632332653baa',
#   'name': None,
#   'timestamp': '2023-02-27T19:34:59.295Z',
#   'batchId': 4062,
#   'numInputRows': 5,
#   'inputRowsPerSecond': 35.97122302158273,
#   'processedRowsPerSecond': 48.07692307692308,
#   'durationMs': {'addBatch': 37,
#    'getBatch': 1,
#    'getEndOffset': 0,
#    'queryPlanning': 8,
#    'setOffsetRange': 2,
#    'triggerExecution': 104,
#    'walCommit': 32},
#   'stateOperators': [],
#   'sources': [{'description': 'KafkaV2[Subscribe[input_inessa.zabelina]]',
#     'startOffset': {'input_inessa.zabelina': {'0': 25305}},
#     'endOffset': {'input_inessa.zabelina': {'0': 25310}},
#     'numInputRows': 5,
#     'inputRowsPerSecond': 35.97122302158273,
#     'processedRowsPerSecond': 48.07692307692308}],
#   'sink': {'description': 'org.apache.spark.sql.kafka010.KafkaSourceProvider@62f8529a'}},
#  {'id': 'ba1dd17e-31f7-4106-b520-f301924999af',
#   'runId': 'cfebd165-bbbf-4244-8239-632332653baa',
#   'name': None,
#   'timestamp': '2023-02-27T19:34:59.399Z',
#   'batchId': 4063,
#   'numInputRows': 5,
#   'inputRowsPerSecond': 48.07692307692308,
#   'processedRowsPerSecond': 46.728971962616825,
#   'durationMs': {'addBatch': 32,
#    'getBatch': 1,
#    'getEndOffset': 0,
#    'queryPlanning': 8,
#    'setOffsetRange': 3,
#    'triggerExecution': 107,
#    'walCommit': 35},
#   'stateOperators': [],
#   'sources': [{'description': 'KafkaV2[Subscribe[input_inessa.zabelina]]',
#     'startOffset': {'input_inessa.zabelina': {'0': 25310}},
#     'endOffset': {'input_inessa.zabelina': {'0': 25315}},
#     'numInputRows': 5,
#     'inputRowsPerSecond': 48.07692307692308,
#     'processedRowsPerSecond': 46.728971962616825}],
#   'sink': {'description': 'org.apache.spark.sql.kafka010.KafkaSourceProvider@62f8529a'}},
#  {'id': 'ba1dd17e-31f7-4106-b520-f301924999af',
#   'runId': 'cfebd165-bbbf-4244-8239-632332653baa',
#   'name': None,
#   'timestamp': '2023-02-27T19:34:59.507Z',
#   'batchId': 4064,
#   'numInputRows': 5,
#   'inputRowsPerSecond': 46.2962962962963,
#   'processedRowsPerSecond': 52.63157894736842,
#   'durationMs': {'addBatch': 29,
#    'getBatch': 1,
#    'getEndOffset': 0,
#    'queryPlanning': 7,
#    'setOffsetRange': 3,
#    'triggerExecution': 95,
#    'walCommit': 32},
#   'stateOperators': [],
#   'sources': [{'description': 'KafkaV2[Subscribe[input_inessa.zabelina]]',
#     'startOffset': {'input_inessa.zabelina': {'0': 25315}},
#     'endOffset': {'input_inessa.zabelina': {'0': 25320}},
#     'numInputRows': 5,
#     'inputRowsPerSecond': 46.2962962962963,
#     'processedRowsPerSecond': 52.63157894736842}],
#   'sink': {'description': 'org.apache.spark.sql.kafka010.KafkaSourceProvider@62f8529a'}},
#  {'id': 'ba1dd17e-31f7-4106-b520-f301924999af',
#   'runId': 'cfebd165-bbbf-4244-8239-632332653baa',
#   'name': None,
#   'timestamp': '2023-02-27T19:34:59.602Z',
#   'batchId': 4065,
#   'numInputRows': 5,
#   'inputRowsPerSecond': 52.63157894736842,
#   'processedRowsPerSecond': 50.505050505050505,
#   'durationMs': {'addBatch': 29,
#    'getBatch': 0,
#    'getEndOffset': 1,
#    'queryPlanning': 7,
#    'setOffsetRange': 2,
#    'triggerExecution': 99,
#    'walCommit': 37},
#   'stateOperators': [],
#   'sources': [{'description': 'KafkaV2[Subscribe[input_inessa.zabelina]]',
#     'startOffset': {'input_inessa.zabelina': {'0': 25320}},
#     'endOffset': {'input_inessa.zabelina': {'0': 25325}},
#     'numInputRows': 5,
#     'inputRowsPerSecond': 52.63157894736842,
#     'processedRowsPerSecond': 50.505050505050505}],
#   'sink': {'description': 'org.apache.spark.sql.kafka010.KafkaSourceProvider@62f8529a'}},
#  {'id': 'ba1dd17e-31f7-4106-b520-f301924999af',
#   'runId': 'cfebd165-bbbf-4244-8239-632332653baa',
#   'name': None,
#   'timestamp': '2023-02-27T19:34:59.701Z',
#   'batchId': 4066,
#   'numInputRows': 5,
#   'inputRowsPerSecond': 50.505050505050505,
#   'processedRowsPerSecond': 45.45454545454545,
#   'durationMs': {'addBatch': 33,
#    'getBatch': 1,
#    'getEndOffset': 0,
#    'queryPlanning': 16,
#    'setOffsetRange': 2,
#    'triggerExecution': 110,
#    'walCommit': 36},
#   'stateOperators': [],
#   'sources': [{'description': 'KafkaV2[Subscribe[input_inessa.zabelina]]',
#     'startOffset': {'input_inessa.zabelina': {'0': 25325}},
#     'endOffset': {'input_inessa.zabelina': {'0': 25330}},
#     'numInputRows': 5,
#     'inputRowsPerSecond': 50.505050505050505,
#     'processedRowsPerSecond': 45.45454545454545}],
#   'sink': {'description': 'org.apache.spark.sql.kafka010.KafkaSourceProvider@62f8529a'}},
#  {'id': 'ba1dd17e-31f7-4106-b520-f301924999af',
#   'runId': 'cfebd165-bbbf-4244-8239-632332653baa',
#   'name': None,
#   'timestamp': '2023-02-27T19:34:59.812Z',
#   'batchId': 4067,
#   'numInputRows': 5,
#   'inputRowsPerSecond': 45.04504504504504,
#   'processedRowsPerSecond': 45.45454545454545,
#   'durationMs': {'addBatch': 32,
#    'getBatch': 0,
#    'getEndOffset': 0,
#    'queryPlanning': 19,
#    'setOffsetRange': 2,
#    'triggerExecution': 110,
#    'walCommit': 32},
#   'stateOperators': [],
#   'sources': [{'description': 'KafkaV2[Subscribe[input_inessa.zabelina]]',
#     'startOffset': {'input_inessa.zabelina': {'0': 25330}},
#     'endOffset': {'input_inessa.zabelina': {'0': 25335}},
#     'numInputRows': 5,
#     'inputRowsPerSecond': 45.04504504504504,
#     'processedRowsPerSecond': 45.45454545454545}],
#   'sink': {'description': 'org.apache.spark.sql.kafka010.KafkaSourceProvider@62f8529a'}},
#  {'id': 'ba1dd17e-31f7-4106-b520-f301924999af',
#   'runId': 'cfebd165-bbbf-4244-8239-632332653baa',
#   'name': None,
#   'timestamp': '2023-02-27T19:34:59.923Z',
#   'batchId': 4068,
#   'numInputRows': 5,
#   'inputRowsPerSecond': 45.04504504504504,
#   'processedRowsPerSecond': 45.87155963302752,
#   'durationMs': {'addBatch': 36,
#    'getBatch': 1,
#    'getEndOffset': 0,
#    'queryPlanning': 7,
#    'setOffsetRange': 2,
#    'triggerExecution': 109,
#    'walCommit': 37},
#   'stateOperators': [],
#   'sources': [{'description': 'KafkaV2[Subscribe[input_inessa.zabelina]]',
#     'startOffset': {'input_inessa.zabelina': {'0': 25335}},
#     'endOffset': {'input_inessa.zabelina': {'0': 25340}},
#     'numInputRows': 5,
#     'inputRowsPerSecond': 45.04504504504504,
#     'processedRowsPerSecond': 45.87155963302752}],
#   'sink': {'description': 'org.apache.spark.sql.kafka010.KafkaSourceProvider@62f8529a'}},
#  {'id': 'ba1dd17e-31f7-4106-b520-f301924999af',
#   'runId': 'cfebd165-bbbf-4244-8239-632332653baa',
#   'name': None,
#   'timestamp': '2023-02-27T19:35:00.033Z',
#   'batchId': 4069,
#   'numInputRows': 5,
#   'inputRowsPerSecond': 45.45454545454545,
#   'processedRowsPerSecond': 51.54639175257732,
#   'durationMs': {'addBatch': 30,
#    'getBatch': 0,
#    'getEndOffset': 0,
#    'queryPlanning': 8,
#    'setOffsetRange': 2,
#    'triggerExecution': 97,
#    'walCommit': 34},
#   'stateOperators': [],
#   'sources': [{'description': 'KafkaV2[Subscribe[input_inessa.zabelina]]',
#     'startOffset': {'input_inessa.zabelina': {'0': 25340}},
#     'endOffset': {'input_inessa.zabelina': {'0': 25345}},
#     'numInputRows': 5,
#     'inputRowsPerSecond': 45.45454545454545,
#     'processedRowsPerSecond': 51.54639175257732}],
#   'sink': {'description': 'org.apache.spark.sql.kafka010.KafkaSourceProvider@62f8529a'}},
#  {'id': 'ba1dd17e-31f7-4106-b520-f301924999af',
#   'runId': 'cfebd165-bbbf-4244-8239-632332653baa',
#   'name': None,
#   'timestamp': '2023-02-27T19:35:00.131Z',
#   'batchId': 4070,
#   'numInputRows': 5,
#   'inputRowsPerSecond': 51.0204081632653,
#   'processedRowsPerSecond': 49.01960784313726,
#   'durationMs': {'addBatch': 29,
#    'getBatch': 0,
#    'getEndOffset': 0,
#    'queryPlanning': 7,
#    'setOffsetRange': 1,
#    'triggerExecution': 102,
#    'walCommit': 37},
#   'stateOperators': [],
#   'sources': [{'description': 'KafkaV2[Subscribe[input_inessa.zabelina]]',
#     'startOffset': {'input_inessa.zabelina': {'0': 25345}},
#     'endOffset': {'input_inessa.zabelina': {'0': 25350}},
#     'numInputRows': 5,
#     'inputRowsPerSecond': 51.0204081632653,
#     'processedRowsPerSecond': 49.01960784313726}],
#   'sink': {'description': 'org.apache.spark.sql.kafka010.KafkaSourceProvider@62f8529a'}},
#  {'id': 'ba1dd17e-31f7-4106-b520-f301924999af',
#   'runId': 'cfebd165-bbbf-4244-8239-632332653baa',
#   'name': None,
#   'timestamp': '2023-02-27T19:35:00.233Z',
#   'batchId': 4071,
#   'numInputRows': 5,
#   'inputRowsPerSecond': 49.01960784313726,
#   'processedRowsPerSecond': 49.5049504950495,
#   'durationMs': {'addBatch': 30,
#    'getBatch': 0,
#    'getEndOffset': 0,
#    'queryPlanning': 7,
#    'setOffsetRange': 3,
#    'triggerExecution': 101,
#    'walCommit': 36},
#   'stateOperators': [],
#   'sources': [{'description': 'KafkaV2[Subscribe[input_inessa.zabelina]]',
#     'startOffset': {'input_inessa.zabelina': {'0': 25350}},
#     'endOffset': {'input_inessa.zabelina': {'0': 25355}},
#     'numInputRows': 5,
#     'inputRowsPerSecond': 49.01960784313726,
#     'processedRowsPerSecond': 49.5049504950495}],
#   'sink': {'description': 'org.apache.spark.sql.kafka010.KafkaSourceProvider@62f8529a'}},
#  {'id': 'ba1dd17e-31f7-4106-b520-f301924999af',
#   'runId': 'cfebd165-bbbf-4244-8239-632332653baa',
#   'name': None,
#   'timestamp': '2023-02-27T19:35:00.334Z',
#   'batchId': 4072,
#   'numInputRows': 5,
#   'inputRowsPerSecond': 49.5049504950495,
#   'processedRowsPerSecond': 53.191489361702125,
#   'durationMs': {'addBatch': 27,
#    'getBatch': 0,
#    'getEndOffset': 0,
#    'queryPlanning': 7,
#    'setOffsetRange': 2,
#    'triggerExecution': 94,
#    'walCommit': 35},
#   'stateOperators': [],
#   'sources': [{'description': 'KafkaV2[Subscribe[input_inessa.zabelina]]',
#     'startOffset': {'input_inessa.zabelina': {'0': 25355}},
#     'endOffset': {'input_inessa.zabelina': {'0': 25360}},
#     'numInputRows': 5,
#     'inputRowsPerSecond': 49.5049504950495,
#     'processedRowsPerSecond': 53.191489361702125}],
#   'sink': {'description': 'org.apache.spark.sql.kafka010.KafkaSourceProvider@62f8529a'}},
#  {'id': 'ba1dd17e-31f7-4106-b520-f301924999af',
#   'runId': 'cfebd165-bbbf-4244-8239-632332653baa',
#   'name': None,
#   'timestamp': '2023-02-27T19:35:00.429Z',
#   'batchId': 4073,
#   'numInputRows': 5,
#   'inputRowsPerSecond': 52.63157894736842,
#   'processedRowsPerSecond': 47.61904761904762,
#   'durationMs': {'addBatch': 29,
#    'getBatch': 0,
#    'getEndOffset': 1,
#    'queryPlanning': 6,
#    'setOffsetRange': 3,
#    'triggerExecution': 105,
#    'walCommit': 39},
#   'stateOperators': [],
#   'sources': [{'description': 'KafkaV2[Subscribe[input_inessa.zabelina]]',
#     'startOffset': {'input_inessa.zabelina': {'0': 25360}},
#     'endOffset': {'input_inessa.zabelina': {'0': 25365}},
#     'numInputRows': 5,
#     'inputRowsPerSecond': 52.63157894736842,
#     'processedRowsPerSecond': 47.61904761904762}],
#   'sink': {'description': 'org.apache.spark.sql.kafka010.KafkaSourceProvider@62f8529a'}},
#  {'id': 'ba1dd17e-31f7-4106-b520-f301924999af',
#   'runId': 'cfebd165-bbbf-4244-8239-632332653baa',
#   'name': None,
#   'timestamp': '2023-02-27T19:35:00.535Z',
#   'batchId': 4074,
#   'numInputRows': 5,
#   'inputRowsPerSecond': 47.16981132075472,
#   'processedRowsPerSecond': 46.2962962962963,
#   'durationMs': {'addBatch': 30,
#    'getBatch': 1,
#    'getEndOffset': 0,
#    'queryPlanning': 7,
#    'setOffsetRange': 1,
#    'triggerExecution': 108,
#    'walCommit': 43},
#   'stateOperators': [],
#   'sources': [{'description': 'KafkaV2[Subscribe[input_inessa.zabelina]]',
#     'startOffset': {'input_inessa.zabelina': {'0': 25365}},
#     'endOffset': {'input_inessa.zabelina': {'0': 25370}},
#     'numInputRows': 5,
#     'inputRowsPerSecond': 47.16981132075472,
#     'processedRowsPerSecond': 46.2962962962963}],
#   'sink': {'description': 'org.apache.spark.sql.kafka010.KafkaSourceProvider@62f8529a'}},
#  {'id': 'ba1dd17e-31f7-4106-b520-f301924999af',
#   'runId': 'cfebd165-bbbf-4244-8239-632332653baa',
#   'name': None,
#   'timestamp': '2023-02-27T19:35:00.643Z',
#   'batchId': 4075,
#   'numInputRows': 5,
#   'inputRowsPerSecond': 46.2962962962963,
#   'processedRowsPerSecond': 40.65040650406504,
#   'durationMs': {'addBatch': 34,
#    'getBatch': 0,
#    'getEndOffset': 0,
#    'queryPlanning': 17,
#    'setOffsetRange': 3,
#    'triggerExecution': 123,
#    'walCommit': 40},
#   'stateOperators': [],
#   'sources': [{'description': 'KafkaV2[Subscribe[input_inessa.zabelina]]',
#     'startOffset': {'input_inessa.zabelina': {'0': 25370}},
#     'endOffset': {'input_inessa.zabelina': {'0': 25375}},
#     'numInputRows': 5,
#     'inputRowsPerSecond': 46.2962962962963,
#     'processedRowsPerSecond': 40.65040650406504}],
#   'sink': {'description': 'org.apache.spark.sql.kafka010.KafkaSourceProvider@62f8529a'}},
#  {'id': 'ba1dd17e-31f7-4106-b520-f301924999af',
#   'runId': 'cfebd165-bbbf-4244-8239-632332653baa',
#   'name': None,
#   'timestamp': '2023-02-27T19:35:00.766Z',
#   'batchId': 4076,
#   'numInputRows': 5,
#   'inputRowsPerSecond': 40.65040650406504,
#   'processedRowsPerSecond': 51.54639175257732,
#   'durationMs': {'addBatch': 27,
#    'getBatch': 0,
#    'getEndOffset': 0,
#    'queryPlanning': 7,
#    'setOffsetRange': 2,
#    'triggerExecution': 97,
#    'walCommit': 38},
#   'stateOperators': [],
#   'sources': [{'description': 'KafkaV2[Subscribe[input_inessa.zabelina]]',
#     'startOffset': {'input_inessa.zabelina': {'0': 25375}},
#     'endOffset': {'input_inessa.zabelina': {'0': 25380}},
#     'numInputRows': 5,
#     'inputRowsPerSecond': 40.65040650406504,
#     'processedRowsPerSecond': 51.54639175257732}],
#   'sink': {'description': 'org.apache.spark.sql.kafka010.KafkaSourceProvider@62f8529a'}},
#  {'id': 'ba1dd17e-31f7-4106-b520-f301924999af',
#   'runId': 'cfebd165-bbbf-4244-8239-632332653baa',
#   'name': None,
#   'timestamp': '2023-02-27T19:35:00.863Z',
#   'batchId': 4077,
#   'numInputRows': 5,
#   'inputRowsPerSecond': 51.54639175257732,
#   'processedRowsPerSecond': 48.07692307692308,
#   'durationMs': {'addBatch': 27,
#    'getBatch': 0,
#    'getEndOffset': 0,
#    'queryPlanning': 8,
#    'setOffsetRange': 3,
#    'triggerExecution': 104,
#    'walCommit': 39},
#   'stateOperators': [],
#   'sources': [{'description': 'KafkaV2[Subscribe[input_inessa.zabelina]]',
#     'startOffset': {'input_inessa.zabelina': {'0': 25380}},
#     'endOffset': {'input_inessa.zabelina': {'0': 25385}},
#     'numInputRows': 5,
#     'inputRowsPerSecond': 51.54639175257732,
#     'processedRowsPerSecond': 48.07692307692308}],
#   'sink': {'description': 'org.apache.spark.sql.kafka010.KafkaSourceProvider@62f8529a'}},
#  {'id': 'ba1dd17e-31f7-4106-b520-f301924999af',
#   'runId': 'cfebd165-bbbf-4244-8239-632332653baa',
#   'name': None,
#   'timestamp': '2023-02-27T19:35:00.967Z',
#   'batchId': 4078,
#   'numInputRows': 5,
#   'inputRowsPerSecond': 48.07692307692308,
#   'processedRowsPerSecond': 50.505050505050505,
#   'durationMs': {'addBatch': 28,
#    'getBatch': 1,
#    'getEndOffset': 0,
#    'queryPlanning': 7,
#    'setOffsetRange': 3,
#    'triggerExecution': 99,
#    'walCommit': 35},
#   'stateOperators': [],
#   'sources': [{'description': 'KafkaV2[Subscribe[input_inessa.zabelina]]',
#     'startOffset': {'input_inessa.zabelina': {'0': 25385}},
#     'endOffset': {'input_inessa.zabelina': {'0': 25390}},
#     'numInputRows': 5,
#     'inputRowsPerSecond': 48.07692307692308,
#     'processedRowsPerSecond': 50.505050505050505}],
#   'sink': {'description': 'org.apache.spark.sql.kafka010.KafkaSourceProvider@62f8529a'}},
#  {'id': 'ba1dd17e-31f7-4106-b520-f301924999af',
#   'runId': 'cfebd165-bbbf-4244-8239-632332653baa',
#   'name': None,
#   'timestamp': '2023-02-27T19:35:01.066Z',
#   'batchId': 4079,
#   'numInputRows': 5,
#   'inputRowsPerSecond': 50.505050505050505,
#   'processedRowsPerSecond': 37.31343283582089,
#   'durationMs': {'addBatch': 59,
#    'getBatch': 0,
#    'getEndOffset': 1,
#    'queryPlanning': 8,
#    'setOffsetRange': 3,
#    'triggerExecution': 134,
#    'walCommit': 37},
#   'stateOperators': [],
#   'sources': [{'description': 'KafkaV2[Subscribe[input_inessa.zabelina]]',
#     'startOffset': {'input_inessa.zabelina': {'0': 25390}},
#     'endOffset': {'input_inessa.zabelina': {'0': 25395}},
#     'numInputRows': 5,
#     'inputRowsPerSecond': 50.505050505050505,
#     'processedRowsPerSecond': 37.31343283582089}],
#   'sink': {'description': 'org.apache.spark.sql.kafka010.KafkaSourceProvider@62f8529a'}},
#  {'id': 'ba1dd17e-31f7-4106-b520-f301924999af',
#   'runId': 'cfebd165-bbbf-4244-8239-632332653baa',
#   'name': None,
#   'timestamp': '2023-02-27T19:35:01.200Z',
#   'batchId': 4080,
#   'numInputRows': 5,
#   'inputRowsPerSecond': 37.31343283582089,
#   'processedRowsPerSecond': 50.0,
#   'durationMs': {'addBatch': 30,
#    'getBatch': 0,
#    'getEndOffset': 0,
#    'queryPlanning': 8,
#    'setOffsetRange': 3,
#    'triggerExecution': 100,
#    'walCommit': 38},
#   'stateOperators': [],
#   'sources': [{'description': 'KafkaV2[Subscribe[input_inessa.zabelina]]',
#     'startOffset': {'input_inessa.zabelina': {'0': 25395}},
#     'endOffset': {'input_inessa.zabelina': {'0': 25400}},
#     'numInputRows': 5,
#     'inputRowsPerSecond': 37.31343283582089,
#     'processedRowsPerSecond': 50.0}],
#   'sink': {'description': 'org.apache.spark.sql.kafka010.KafkaSourceProvider@62f8529a'}},
#  {'id': 'ba1dd17e-31f7-4106-b520-f301924999af',
#   'runId': 'cfebd165-bbbf-4244-8239-632332653baa',
#   'name': None,
#   'timestamp': '2023-02-27T19:35:01.301Z',
#   'batchId': 4081,
#   'numInputRows': 5,
#   'inputRowsPerSecond': 49.5049504950495,
#   'processedRowsPerSecond': 49.5049504950495,
#   'durationMs': {'addBatch': 30,
#    'getBatch': 0,
#    'getEndOffset': 0,
#    'queryPlanning': 7,
#    'setOffsetRange': 3,
#    'triggerExecution': 101,
#    'walCommit': 37},
#   'stateOperators': [],
#   'sources': [{'description': 'KafkaV2[Subscribe[input_inessa.zabelina]]',
#     'startOffset': {'input_inessa.zabelina': {'0': 25400}},
#     'endOffset': {'input_inessa.zabelina': {'0': 25405}},
#     'numInputRows': 5,
#     'inputRowsPerSecond': 49.5049504950495,
#     'processedRowsPerSecond': 49.5049504950495}],
#   'sink': {'description': 'org.apache.spark.sql.kafka010.KafkaSourceProvider@62f8529a'}},
#  {'id': 'ba1dd17e-31f7-4106-b520-f301924999af',
#   'runId': 'cfebd165-bbbf-4244-8239-632332653baa',
#   'name': None,
#   'timestamp': '2023-02-27T19:35:01.402Z',
#   'batchId': 4082,
#   'numInputRows': 5,
#   'inputRowsPerSecond': 49.5049504950495,
#   'processedRowsPerSecond': 51.54639175257732,
#   'durationMs': {'addBatch': 29,
#    'getBatch': 1,
#    'getEndOffset': 0,
#    'queryPlanning': 7,
#    'setOffsetRange': 2,
#    'triggerExecution': 97,
#    'walCommit': 33},
#   'stateOperators': [],
#   'sources': [{'description': 'KafkaV2[Subscribe[input_inessa.zabelina]]',
#     'startOffset': {'input_inessa.zabelina': {'0': 25405}},
#     'endOffset': {'input_inessa.zabelina': {'0': 25410}},
#     'numInputRows': 5,
#     'inputRowsPerSecond': 49.5049504950495,
#     'processedRowsPerSecond': 51.54639175257732}],
#   'sink': {'description': 'org.apache.spark.sql.kafka010.KafkaSourceProvider@62f8529a'}},
#  {'id': 'ba1dd17e-31f7-4106-b520-f301924999af',
#   'runId': 'cfebd165-bbbf-4244-8239-632332653baa',
#   'name': None,
#   'timestamp': '2023-02-27T19:35:01.500Z',
#   'batchId': 4083,
#   'numInputRows': 5,
#   'inputRowsPerSecond': 51.0204081632653,
#   'processedRowsPerSecond': 46.728971962616825,
#   'durationMs': {'addBatch': 28,
#    'getBatch': 0,
#    'getEndOffset': 0,
#    'queryPlanning': 6,
#    'setOffsetRange': 2,
#    'triggerExecution': 107,
#    'walCommit': 43},
#   'stateOperators': [],
#   'sources': [{'description': 'KafkaV2[Subscribe[input_inessa.zabelina]]',
#     'startOffset': {'input_inessa.zabelina': {'0': 25410}},
#     'endOffset': {'input_inessa.zabelina': {'0': 25415}},
#     'numInputRows': 5,
#     'inputRowsPerSecond': 51.0204081632653,
#     'processedRowsPerSecond': 46.728971962616825}],
#   'sink': {'description': 'org.apache.spark.sql.kafka010.KafkaSourceProvider@62f8529a'}},
#  {'id': 'ba1dd17e-31f7-4106-b520-f301924999af',
#   'runId': 'cfebd165-bbbf-4244-8239-632332653baa',
#   'name': None,
#   'timestamp': '2023-02-27T19:35:01.608Z',
#   'batchId': 4084,
#   'numInputRows': 5,
#   'inputRowsPerSecond': 46.2962962962963,
#   'processedRowsPerSecond': 35.71428571428571,
#   'durationMs': {'addBatch': 58,
#    'getBatch': 1,
#    'getEndOffset': 1,
#    'queryPlanning': 9,
#    'setOffsetRange': 2,
#    'triggerExecution': 140,
#    'walCommit': 42},
#   'stateOperators': [],
#   'sources': [{'description': 'KafkaV2[Subscribe[input_inessa.zabelina]]',
#     'startOffset': {'input_inessa.zabelina': {'0': 25415}},
#     'endOffset': {'input_inessa.zabelina': {'0': 25420}},
#     'numInputRows': 5,
#     'inputRowsPerSecond': 46.2962962962963,
#     'processedRowsPerSecond': 35.71428571428571}],
#   'sink': {'description': 'org.apache.spark.sql.kafka010.KafkaSourceProvider@62f8529a'}},
#  {'id': 'ba1dd17e-31f7-4106-b520-f301924999af',
#   'runId': 'cfebd165-bbbf-4244-8239-632332653baa',
#   'name': None,
#   'timestamp': '2023-02-27T19:35:01.749Z',
#   'batchId': 4085,
#   'numInputRows': 5,
#   'inputRowsPerSecond': 35.46099290780142,
#   'processedRowsPerSecond': 43.103448275862064,
#   'durationMs': {'addBatch': 33,
#    'getBatch': 0,
#    'getEndOffset': 0,
#    'queryPlanning': 11,
#    'setOffsetRange': 2,
#    'triggerExecution': 116,
#    'walCommit': 44},
#   'stateOperators': [],
#   'sources': [{'description': 'KafkaV2[Subscribe[input_inessa.zabelina]]',
#     'startOffset': {'input_inessa.zabelina': {'0': 25420}},
#     'endOffset': {'input_inessa.zabelina': {'0': 25425}},
#     'numInputRows': 5,
#     'inputRowsPerSecond': 35.46099290780142,
#     'processedRowsPerSecond': 43.103448275862064}],
#   'sink': {'description': 'org.apache.spark.sql.kafka010.KafkaSourceProvider@62f8529a'}},
#  {'id': 'ba1dd17e-31f7-4106-b520-f301924999af',
#   'runId': 'cfebd165-bbbf-4244-8239-632332653baa',
#   'name': None,
#   'timestamp': '2023-02-27T19:35:01.866Z',
#   'batchId': 4086,
#   'numInputRows': 5,
#   'inputRowsPerSecond': 42.73504273504273,
#   'processedRowsPerSecond': 46.728971962616825,
#   'durationMs': {'addBatch': 35,
#    'getBatch': 1,
#    'getEndOffset': 1,
#    'queryPlanning': 8,
#    'setOffsetRange': 1,
#    'triggerExecution': 107,
#    'walCommit': 36},
#   'stateOperators': [],
#   'sources': [{'description': 'KafkaV2[Subscribe[input_inessa.zabelina]]',
#     'startOffset': {'input_inessa.zabelina': {'0': 25425}},
#     'endOffset': {'input_inessa.zabelina': {'0': 25430}},
#     'numInputRows': 5,
#     'inputRowsPerSecond': 42.73504273504273,
#     'processedRowsPerSecond': 46.728971962616825}],
#   'sink': {'description': 'org.apache.spark.sql.kafka010.KafkaSourceProvider@62f8529a'}},
#  {'id': 'ba1dd17e-31f7-4106-b520-f301924999af',
#   'runId': 'cfebd165-bbbf-4244-8239-632332653baa',
#   'name': None,
#   'timestamp': '2023-02-27T19:35:01.973Z',
#   'batchId': 4087,
#   'numInputRows': 5,
#   'inputRowsPerSecond': 46.728971962616825,
#   'processedRowsPerSecond': 46.2962962962963,
#   'durationMs': {'addBatch': 31,
#    'getBatch': 1,
#    'getEndOffset': 0,
#    'queryPlanning': 7,
#    'setOffsetRange': 2,
#    'triggerExecution': 108,
#    'walCommit': 43},
#   'stateOperators': [],
#   'sources': [{'description': 'KafkaV2[Subscribe[input_inessa.zabelina]]',
#     'startOffset': {'input_inessa.zabelina': {'0': 25430}},
#     'endOffset': {'input_inessa.zabelina': {'0': 25435}},
#     'numInputRows': 5,
#     'inputRowsPerSecond': 46.728971962616825,
#     'processedRowsPerSecond': 46.2962962962963}],
#   'sink': {'description': 'org.apache.spark.sql.kafka010.KafkaSourceProvider@62f8529a'}},
#  {'id': 'ba1dd17e-31f7-4106-b520-f301924999af',
#   'runId': 'cfebd165-bbbf-4244-8239-632332653baa',
#   'name': None,
#   'timestamp': '2023-02-27T19:35:02.081Z',
#   'batchId': 4088,
#   'numInputRows': 5,
#   'inputRowsPerSecond': 46.2962962962963,
#   'processedRowsPerSecond': 48.07692307692308,
#   'durationMs': {'addBatch': 32,
#    'getBatch': 1,
#    'getEndOffset': 0,
#    'queryPlanning': 7,
#    'setOffsetRange': 3,
# ...
#   'sink': {'description': 'org.apache.spark.sql.kafka010.KafkaSourceProvider@62f8529a'}},
#  {'id': 'ba1dd17e-31f7-4106-b520-f301924999af',
#   'runId': 'cfebd165-bbbf-4244-8239-632332653baa',
#   'name': None,
#   'timestamp': '2023-02-27T19:35:04.947Z',
#   'batchId': 4115,
#   'numInputRows': 5,
#   'inputRowsPerSecond': 49.5049504950495,
#   'processedRowsPerSecond': 51.54639175257732,
#   'durationMs': {'addBatch': 27,
#    'getBatch': 1,
#    'getEndOffset': 0,
#    'queryPlanning': 7,
#    'setOffsetRange': 5,
#    'triggerExecution': 97,
#    'walCommit': 33},
#   'stateOperators': [],
#   'sources': [{'description': 'KafkaV2[Subscribe[input_inessa.zabelina]]',
#     'startOffset': {'input_inessa.zabelina': {'0': 25570}},
#     'endOffset': {'input_inessa.zabelina': {'0': 25575}},
#     'numInputRows': 5,
#     'inputRowsPerSecond': 49.5049504950495,
#     'processedRowsPerSecond': 51.54639175257732}],
#   'sink': {'description': 'org.apache.spark.sql.kafka010.KafkaSourceProvider@62f8529a'}},
#  {'id': 'ba1dd17e-31f7-4106-b520-f301924999af',
#   'runId': 'cfebd165-bbbf-4244-8239-632332653baa',
#   'name': None,
#   'timestamp': '2023-02-27T19:35:05.045Z',
#   'batchId': 4116,
#   'numInputRows': 5,
#   'inputRowsPerSecond': 51.0204081632653,
#   'processedRowsPerSecond': 56.81818181818182,
#   'durationMs': {'addBatch': 26,
#    'getBatch': 0,
#    'getEndOffset': 0,
#    'queryPlanning': 7,
#    'setOffsetRange': 3,
#    'triggerExecution': 88,
#    'walCommit': 31},
#   'stateOperators': [],
#   'sources': [{'description': 'KafkaV2[Subscribe[input_inessa.zabelina]]',
#     'startOffset': {'input_inessa.zabelina': {'0': 25575}},
#     'endOffset': {'input_inessa.zabelina': {'0': 25580}},
#     'numInputRows': 5,
#     'inputRowsPerSecond': 51.0204081632653,
#     'processedRowsPerSecond': 56.81818181818182}],
#   'sink': {'description': 'org.apache.spark.sql.kafka010.KafkaSourceProvider@62f8529a'}},
#  {'id': 'ba1dd17e-31f7-4106-b520-f301924999af',
#   'runId': 'cfebd165-bbbf-4244-8239-632332653baa',
#   'name': None,
#   'timestamp': '2023-02-27T19:35:05.133Z',
#   'batchId': 4117,
#   'numInputRows': 5,
#   'inputRowsPerSecond': 56.81818181818182,
#   'processedRowsPerSecond': 51.0204081632653,
#   'durationMs': {'addBatch': 32,
#    'getBatch': 0,
#    'getEndOffset': 1,
#    'queryPlanning': 7,
#    'setOffsetRange': 1,
#    'triggerExecution': 98,
#    'walCommit': 30},
#   'stateOperators': [],
#   'sources': [{'description': 'KafkaV2[Subscribe[input_inessa.zabelina]]',
#     'startOffset': {'input_inessa.zabelina': {'0': 25580}},
#     'endOffset': {'input_inessa.zabelina': {'0': 25585}},
#     'numInputRows': 5,
#     'inputRowsPerSecond': 56.81818181818182,
#     'processedRowsPerSecond': 51.0204081632653}],
#   'sink': {'description': 'org.apache.spark.sql.kafka010.KafkaSourceProvider@62f8529a'}},
#  {'id': 'ba1dd17e-31f7-4106-b520-f301924999af',
#   'runId': 'cfebd165-bbbf-4244-8239-632332653baa',
#   'name': None,
#   'timestamp': '2023-02-27T19:35:05.231Z',
#   'batchId': 4118,
#   'numInputRows': 5,
#   'inputRowsPerSecond': 51.0204081632653,
#   'processedRowsPerSecond': 42.73504273504273,
#   'durationMs': {'addBatch': 53,
#    'getBatch': 0,
#    'getEndOffset': 0,
#    'queryPlanning': 7,
#    'setOffsetRange': 2,
#    'triggerExecution': 117,
#    'walCommit': 32},
#   'stateOperators': [],
#   'sources': [{'description': 'KafkaV2[Subscribe[input_inessa.zabelina]]',
#     'startOffset': {'input_inessa.zabelina': {'0': 25585}},
#     'endOffset': {'input_inessa.zabelina': {'0': 25590}},
#     'numInputRows': 5,
#     'inputRowsPerSecond': 51.0204081632653,
#     'processedRowsPerSecond': 42.73504273504273}],
#   'sink': {'description': 'org.apache.spark.sql.kafka010.KafkaSourceProvider@62f8529a'}},
#  {'id': 'ba1dd17e-31f7-4106-b520-f301924999af',
#   'runId': 'cfebd165-bbbf-4244-8239-632332653baa',
#   'name': None,
#   'timestamp': '2023-02-27T19:35:05.348Z',
#   'batchId': 4119,
#   'numInputRows': 5,
#   'inputRowsPerSecond': 42.73504273504273,
#   'processedRowsPerSecond': 54.94505494505495,
#   'durationMs': {'addBatch': 30,
#    'getBatch': 0,
#    'getEndOffset': 0,
#    'queryPlanning': 7,
#    'setOffsetRange': 2,
#    'triggerExecution': 91,
#    'walCommit': 32},
#   'stateOperators': [],
#   'sources': [{'description': 'KafkaV2[Subscribe[input_inessa.zabelina]]',
#     'startOffset': {'input_inessa.zabelina': {'0': 25590}},
#     'endOffset': {'input_inessa.zabelina': {'0': 25595}},
#     'numInputRows': 5,
#     'inputRowsPerSecond': 42.73504273504273,
#     'processedRowsPerSecond': 54.94505494505495}],
#   'sink': {'description': 'org.apache.spark.sql.kafka010.KafkaSourceProvider@62f8529a'}},
#  {'id': 'ba1dd17e-31f7-4106-b520-f301924999af',
#   'runId': 'cfebd165-bbbf-4244-8239-632332653baa',
#   'name': None,
#   'timestamp': '2023-02-27T19:35:05.439Z',
#   'batchId': 4120,
#   'numInputRows': 5,
#   'inputRowsPerSecond': 54.94505494505495,
#   'processedRowsPerSecond': 54.94505494505495,
#   'durationMs': {'addBatch': 30,
#    'getBatch': 0,
#    'getEndOffset': 0,
#    'queryPlanning': 7,
#    'setOffsetRange': 2,
#    'triggerExecution': 91,
#    'walCommit': 29},
#   'stateOperators': [],
#   'sources': [{'description': 'KafkaV2[Subscribe[input_inessa.zabelina]]',
#     'startOffset': {'input_inessa.zabelina': {'0': 25595}},
#     'endOffset': {'input_inessa.zabelina': {'0': 25600}},
#     'numInputRows': 5,
#     'inputRowsPerSecond': 54.94505494505495,
#     'processedRowsPerSecond': 54.94505494505495}],
#   'sink': {'description': 'org.apache.spark.sql.kafka010.KafkaSourceProvider@62f8529a'}},
#  {'id': 'ba1dd17e-31f7-4106-b520-f301924999af',
#   'runId': 'cfebd165-bbbf-4244-8239-632332653baa',
#   'name': None,
#   'timestamp': '2023-02-27T19:35:05.531Z',
#   'batchId': 4121,
#   'numInputRows': 5,
#   'inputRowsPerSecond': 54.34782608695652,
#   'processedRowsPerSecond': 56.81818181818182,
#   'durationMs': {'addBatch': 30,
#    'getBatch': 0,
#    'getEndOffset': 0,
#    'queryPlanning': 6,
#    'setOffsetRange': 1,
#    'triggerExecution': 88,
#    'walCommit': 30},
#   'stateOperators': [],
#   'sources': [{'description': 'KafkaV2[Subscribe[input_inessa.zabelina]]',
#     'startOffset': {'input_inessa.zabelina': {'0': 25600}},
#     'endOffset': {'input_inessa.zabelina': {'0': 25605}},
#     'numInputRows': 5,
#     'inputRowsPerSecond': 54.34782608695652,
#     'processedRowsPerSecond': 56.81818181818182}],
#   'sink': {'description': 'org.apache.spark.sql.kafka010.KafkaSourceProvider@62f8529a'}},
#  {'id': 'ba1dd17e-31f7-4106-b520-f301924999af',
#   'runId': 'cfebd165-bbbf-4244-8239-632332653baa',
#   'name': None,
#   'timestamp': '2023-02-27T19:35:05.619Z',
#   'batchId': 4122,
#   'numInputRows': 5,
#   'inputRowsPerSecond': 56.81818181818182,
#   'processedRowsPerSecond': 52.63157894736842,
#   'durationMs': {'addBatch': 31,
#    'getBatch': 0,
#    'getEndOffset': 0,
#    'queryPlanning': 10,
#    'setOffsetRange': 2,
#    'triggerExecution': 95,
#    'walCommit': 30},
#   'stateOperators': [],
#   'sources': [{'description': 'KafkaV2[Subscribe[input_inessa.zabelina]]',
#     'startOffset': {'input_inessa.zabelina': {'0': 25605}},
#     'endOffset': {'input_inessa.zabelina': {'0': 25610}},
#     'numInputRows': 5,
#     'inputRowsPerSecond': 56.81818181818182,
#     'processedRowsPerSecond': 52.63157894736842}],
#   'sink': {'description': 'org.apache.spark.sql.kafka010.KafkaSourceProvider@62f8529a'}},
#  {'id': 'ba1dd17e-31f7-4106-b520-f301924999af',
#   'runId': 'cfebd165-bbbf-4244-8239-632332653baa',
#   'name': None,
#   'timestamp': '2023-02-27T19:35:05.714Z',
#   'batchId': 4123,
#   'numInputRows': 5,
#   'inputRowsPerSecond': 52.63157894736842,
#   'processedRowsPerSecond': 41.66666666666667,
#   'durationMs': {'addBatch': 56,
#    'getBatch': 0,
#    'getEndOffset': 0,
#    'queryPlanning': 7,
#    'setOffsetRange': 2,
#    'triggerExecution': 120,
#    'walCommit': 32},
#   'stateOperators': [],
#   'sources': [{'description': 'KafkaV2[Subscribe[input_inessa.zabelina]]',
#     'startOffset': {'input_inessa.zabelina': {'0': 25610}},
#     'endOffset': {'input_inessa.zabelina': {'0': 25615}},
#     'numInputRows': 5,
#     'inputRowsPerSecond': 52.63157894736842,
#     'processedRowsPerSecond': 41.66666666666667}],
#   'sink': {'description': 'org.apache.spark.sql.kafka010.KafkaSourceProvider@62f8529a'}},
#  {'id': 'ba1dd17e-31f7-4106-b520-f301924999af',
#   'runId': 'cfebd165-bbbf-4244-8239-632332653baa',
#   'name': None,
#   'timestamp': '2023-02-27T19:35:05.834Z',
#   'batchId': 4124,
#   'numInputRows': 5,
#   'inputRowsPerSecond': 41.66666666666667,
#   'processedRowsPerSecond': 57.4712643678161,
#   'durationMs': {'addBatch': 27,
#    'getBatch': 0,
#    'getEndOffset': 0,
#    'queryPlanning': 7,
#    'setOffsetRange': 3,
#    'triggerExecution': 87,
#    'walCommit': 30},
#   'stateOperators': [],
#   'sources': [{'description': 'KafkaV2[Subscribe[input_inessa.zabelina]]',
#     'startOffset': {'input_inessa.zabelina': {'0': 25615}},
#     'endOffset': {'input_inessa.zabelina': {'0': 25620}},
#     'numInputRows': 5,
#     'inputRowsPerSecond': 41.66666666666667,
#     'processedRowsPerSecond': 57.4712643678161}],
#   'sink': {'description': 'org.apache.spark.sql.kafka010.KafkaSourceProvider@62f8529a'}},
#  {'id': 'ba1dd17e-31f7-4106-b520-f301924999af',
#   'runId': 'cfebd165-bbbf-4244-8239-632332653baa',
#   'name': None,
#   'timestamp': '2023-02-27T19:35:05.921Z',
#   'batchId': 4125,
#   'numInputRows': 5,
#   'inputRowsPerSecond': 57.4712643678161,
#   'processedRowsPerSecond': 43.47826086956522,
#   'durationMs': {'addBatch': 42,
#    'getBatch': 0,
#    'getEndOffset': 0,
#    'queryPlanning': 7,
#    'setOffsetRange': 2,
#    'triggerExecution': 115,
#    'walCommit': 33},
#   'stateOperators': [],
#   'sources': [{'description': 'KafkaV2[Subscribe[input_inessa.zabelina]]',
#     'startOffset': {'input_inessa.zabelina': {'0': 25620}},
#     'endOffset': {'input_inessa.zabelina': {'0': 25625}},
#     'numInputRows': 5,
#     'inputRowsPerSecond': 57.4712643678161,
#     'processedRowsPerSecond': 43.47826086956522}],
#   'sink': {'description': 'org.apache.spark.sql.kafka010.KafkaSourceProvider@62f8529a'}},
#  {'id': 'ba1dd17e-31f7-4106-b520-f301924999af',
#   'runId': 'cfebd165-bbbf-4244-8239-632332653baa',
#   'name': None,
#   'timestamp': '2023-02-27T19:35:06.037Z',
#   'batchId': 4126,
#   'numInputRows': 5,
#   'inputRowsPerSecond': 43.103448275862064,
#   'processedRowsPerSecond': 53.763440860215056,
#   'durationMs': {'addBatch': 32,
#    'getBatch': 0,
#    'getEndOffset': 0,
#    'queryPlanning': 7,
#    'setOffsetRange': 2,
#    'triggerExecution': 93,
#    'walCommit': 29},
#   'stateOperators': [],
#   'sources': [{'description': 'KafkaV2[Subscribe[input_inessa.zabelina]]',
#     'startOffset': {'input_inessa.zabelina': {'0': 25625}},
#     'endOffset': {'input_inessa.zabelina': {'0': 25630}},
#     'numInputRows': 5,
#     'inputRowsPerSecond': 43.103448275862064,
#     'processedRowsPerSecond': 53.763440860215056}],
#   'sink': {'description': 'org.apache.spark.sql.kafka010.KafkaSourceProvider@62f8529a'}},
#  {'id': 'ba1dd17e-31f7-4106-b520-f301924999af',
#   'runId': 'cfebd165-bbbf-4244-8239-632332653baa',
#   'name': None,
#   'timestamp': '2023-02-27T19:35:06.131Z',
#   'batchId': 4127,
#   'numInputRows': 5,
#   'inputRowsPerSecond': 53.191489361702125,
#   'processedRowsPerSecond': 51.0204081632653,
#   'durationMs': {'addBatch': 36,
#    'getBatch': 0,
#    'getEndOffset': 0,
#    'queryPlanning': 6,
#    'setOffsetRange': 5,
#    'triggerExecution': 98,
#    'walCommit': 30},
#   'stateOperators': [],
#   'sources': [{'description': 'KafkaV2[Subscribe[input_inessa.zabelina]]',
#     'startOffset': {'input_inessa.zabelina': {'0': 25630}},
#     'endOffset': {'input_inessa.zabelina': {'0': 25635}},
#     'numInputRows': 5,
#     'inputRowsPerSecond': 53.191489361702125,
#     'processedRowsPerSecond': 51.0204081632653}],
#   'sink': {'description': 'org.apache.spark.sql.kafka010.KafkaSourceProvider@62f8529a'}},
#  {'id': 'ba1dd17e-31f7-4106-b520-f301924999af',
#   'runId': 'cfebd165-bbbf-4244-8239-632332653baa',
#   'name': None,
#   'timestamp': '2023-02-27T19:35:06.230Z',
#   'batchId': 4128,
#   'numInputRows': 5,
#   'inputRowsPerSecond': 50.505050505050505,
#   'processedRowsPerSecond': 53.191489361702125,
#   'durationMs': {'addBatch': 30,
#    'getBatch': 1,
#    'getEndOffset': 0,
#    'queryPlanning': 8,
#    'setOffsetRange': 3,
#    'triggerExecution': 94,
#    'walCommit': 31},
#   'stateOperators': [],
#   'sources': [{'description': 'KafkaV2[Subscribe[input_inessa.zabelina]]',
#     'startOffset': {'input_inessa.zabelina': {'0': 25635}},
#     'endOffset': {'input_inessa.zabelina': {'0': 25640}},
#     'numInputRows': 5,
#     'inputRowsPerSecond': 50.505050505050505,
#     'processedRowsPerSecond': 53.191489361702125}],
#   'sink': {'description': 'org.apache.spark.sql.kafka010.KafkaSourceProvider@62f8529a'}},
#  {'id': 'ba1dd17e-31f7-4106-b520-f301924999af',
#   'runId': 'cfebd165-bbbf-4244-8239-632332653baa',
#   'name': None,
#   'timestamp': '2023-02-27T19:35:06.324Z',
#   'batchId': 4129,
#   'numInputRows': 5,
#   'inputRowsPerSecond': 53.191489361702125,
#   'processedRowsPerSecond': 57.4712643678161,
#   'durationMs': {'addBatch': 27,
#    'getBatch': 0,
#    'getEndOffset': 0,
#    'queryPlanning': 7,
#    'setOffsetRange': 2,
#    'triggerExecution': 87,
#    'walCommit': 30},
#   'stateOperators': [],
#   'sources': [{'description': 'KafkaV2[Subscribe[input_inessa.zabelina]]',
#     'startOffset': {'input_inessa.zabelina': {'0': 25640}},
#     'endOffset': {'input_inessa.zabelina': {'0': 25645}},
#     'numInputRows': 5,
#     'inputRowsPerSecond': 53.191489361702125,
#     'processedRowsPerSecond': 57.4712643678161}],
#   'sink': {'description': 'org.apache.spark.sql.kafka010.KafkaSourceProvider@62f8529a'}},
#  {'id': 'ba1dd17e-31f7-4106-b520-f301924999af',
#   'runId': 'cfebd165-bbbf-4244-8239-632332653baa',
#   'name': None,
#   'timestamp': '2023-02-27T19:35:06.411Z',
#   'batchId': 4130,
#   'numInputRows': 5,
#   'inputRowsPerSecond': 57.4712643678161,
#   'processedRowsPerSecond': 57.4712643678161,
#   'durationMs': {'addBatch': 29,
#    'getBatch': 0,
#    'getEndOffset': 0,
#    'queryPlanning': 7,
#    'setOffsetRange': 2,
#    'triggerExecution': 87,
#    'walCommit': 29},
#   'stateOperators': [],
#   'sources': [{'description': 'KafkaV2[Subscribe[input_inessa.zabelina]]',
#     'startOffset': {'input_inessa.zabelina': {'0': 25645}},
#     'endOffset': {'input_inessa.zabelina': {'0': 25650}},
#     'numInputRows': 5,
#     'inputRowsPerSecond': 57.4712643678161,
#     'processedRowsPerSecond': 57.4712643678161}],
#   'sink': {'description': 'org.apache.spark.sql.kafka010.KafkaSourceProvider@62f8529a'}},
#  {'id': 'ba1dd17e-31f7-4106-b520-f301924999af',
#   'runId': 'cfebd165-bbbf-4244-8239-632332653baa',
#   'name': None,
#   'timestamp': '2023-02-27T19:35:06.498Z',
#   'batchId': 4131,
#   'numInputRows': 5,
#   'inputRowsPerSecond': 57.4712643678161,
#   'processedRowsPerSecond': 54.94505494505495,
#   'durationMs': {'addBatch': 33,
#    'getBatch': 0,
#    'getEndOffset': 0,
#    'queryPlanning': 7,
#    'setOffsetRange': 2,
#    'triggerExecution': 91,
#    'walCommit': 28},
#   'stateOperators': [],
#   'sources': [{'description': 'KafkaV2[Subscribe[input_inessa.zabelina]]',
#     'startOffset': {'input_inessa.zabelina': {'0': 25650}},
#     'endOffset': {'input_inessa.zabelina': {'0': 25655}},
#     'numInputRows': 5,
#     'inputRowsPerSecond': 57.4712643678161,
#     'processedRowsPerSecond': 54.94505494505495}],
#   'sink': {'description': 'org.apache.spark.sql.kafka010.KafkaSourceProvider@62f8529a'}},
#  {'id': 'ba1dd17e-31f7-4106-b520-f301924999af',
#   'runId': 'cfebd165-bbbf-4244-8239-632332653baa',
#   'name': None,
#   'timestamp': '2023-02-27T19:35:06.589Z',
#   'batchId': 4132,
#   'numInputRows': 5,
#   'inputRowsPerSecond': 54.94505494505495,
#   'processedRowsPerSecond': 40.98360655737705,
#   'durationMs': {'addBatch': 66,
#    'getBatch': 0,
#    'getEndOffset': 0,
#    'queryPlanning': 6,
#    'setOffsetRange': 2,
#    'triggerExecution': 122,
#    'walCommit': 27},
#   'stateOperators': [],
#   'sources': [{'description': 'KafkaV2[Subscribe[input_inessa.zabelina]]',
#     'startOffset': {'input_inessa.zabelina': {'0': 25655}},
#     'endOffset': {'input_inessa.zabelina': {'0': 25660}},
#     'numInputRows': 5,
#     'inputRowsPerSecond': 54.94505494505495,
#     'processedRowsPerSecond': 40.98360655737705}],
#   'sink': {'description': 'org.apache.spark.sql.kafka010.KafkaSourceProvider@62f8529a'}}]

# %%
# kafka_read_df = (spark.readStream
#                  .format("kafka")
#                  .option("kafka.bootstrap.servers", KAFKA_BOOTSTRAP_SERVER)
#                  .option("subscribe", KAFKA_INPUT_TOPIC)
#                  .option("startingOffsets", "earliest")
#                  .option("failOnDataLoss", "False")
#                  .load()
# )

# %%
# event_schema = StructType([
#     StructField("uid", StringType(), True),
#     StructField("visits", StringType(), True),
# ])

# visits_schema = ArrayType(
#         StructType([
#             StructField("url", StringType(), True),
#             StructField("timestamp", LongType(), True)
#         ])
# )

# %%
# clean_df = (
#     kafka_read_df
#     .select(f.col('value').cast('string').alias('value'))
#     .select(f.from_json(f.col('value'), event_schema).alias('event'))
#     .select('event.uid',f.from_json(f.col('event.visits'), visits_schema).alias('visits'))
# )

# %%
# lab_model = PipelineModel.load("/user/inessa.zabelina/labs/lab4_model")

# %%
#извлечение url
#применение модели, сохранение предсказаний в predictions_df

# proc_df = clean_df\
#     .withColumn("visit", f.explode("visits").alias("visits"))\
#     .withColumn("host", 
#                 regexp_replace(expr("parse_url(visit.url), 'HOST'").alias("host")), "^www.", "")\
#     .filter("age != '-'")\
#     .filter("gender != '-'")\    
#     .drop("visits", "visit")\
#     .groupBy("uid")\
#     .agg(collect_list("host").alias("hosts"))
    
# predictions_df = lab_model\
#     .transform(proc_df)\
#     .select("uid", "PredictedGender", "PredictedAge")\
#     .withColumnRenamed("PredictedAge", "age")\
#     .withColumnRenamed("PredictedGender", "gender")

# %%
# #Оборачивание предсказания обратно в json
# kafka_out_df = (

#     predictions_df
#     .select(f.to_json(f.struct(*predictions_df.columns)).alias('value'))
# )


# #запись в выходной топик

# sink = (
#     kafka_out_df
#     .writeStream
#     .format('kafka')
#     .options("kafka.bootstrap.servers", KAFKA_BOOTSTRAP_SERVER)
#     .options("topic", KAFKA_OUTPUT_TOPIC)
#     .option("checkpointLocation", 'streaming/chk/chk_kafka')
#     .outputMode("append")
# )

# %%
# sq = sink.start()

# %%
def kill_all():
    streams = SparkSession.builder.getOrCreate().streams.active
    for s in streams:
        desc = s.lastProgress["sources"][0]["description"]
        s.stop()
        print("Stopped {s}".format(s=desc))

# %%
kill_all()
# Out:
# Stopped KafkaV2[Subscribe[input_inessa.zabelina]]

# %%
sc.stop()
