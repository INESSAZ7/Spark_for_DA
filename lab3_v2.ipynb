# %%
import os
import sys
os.environ["PYSPARK_PYTHON"]='/opt/anaconda/envs/bd9/bin/python'
os.environ["SPARK_HOME"]='/usr/hdp/current/spark2-client'
os.environ["PYSPARK_SUBMIT_ARGS"]='--num-executors 5 --executor-memory 4g --executor-cores 1 --driver-memory 2g pyspark-shell'

spark_home = os.environ.get('SPARK_HOME', None)
if not spark_home:
    raise ValueError('SPARK_HOME environment variable is not set')

sys.path.insert(0, os.path.join(spark_home, 'python'))
sys.path.insert(0, os.path.join(spark_home, 'python/lib/py4j-0.10.7-src.zip'))
exec(open(os.path.join(spark_home, 'python/pyspark/shell.py')).read())

# %%
from pyspark import SparkConf
from pyspark.sql import SparkSession

conf = SparkConf()

spark = SparkSession.builder.config(conf=conf).getOrCreate()

# %%
spark

# %%
! hdfs dfs -ls /labs/slaba03/
# Out:
# Found 4 items
# -rw-r--r--   3 hdfs hdfs   91066524 2022-01-06 18:46 /labs/slaba03/laba03_items.csv
# -rw-r--r--   3 hdfs hdfs   29965581 2022-01-06 18:46 /labs/slaba03/laba03_test.csv
# -rw-r--r--   3 hdfs hdfs   74949368 2022-01-06 18:46 /labs/slaba03/laba03_train.csv
# -rw-r--r--   3 hdfs hdfs  871302535 2022-01-06 18:46 /labs/slaba03/laba03_views_programmes.csv

# %%
from pyspark.sql.types import StructType, StructField, StringType, IntegerType, FloatType, ArrayType
from pyspark.sql import functions as F
from pyspark.sql.functions import udf

# %%
from pyspark.ml.feature import Tokenizer, StopWordsRemover, CountVectorizer, IDF, HashingTF
from pyspark.ml import Pipeline

# %% [markdown]
# # train

# %%
schema = StructType([
    StructField("user_id", IntegerType(), True),
    StructField("item_id", IntegerType(), True),
    StructField("purchase", IntegerType(), True),
])

# %%
df_user = spark.read.csv("/labs/slaba03/laba03_train.csv", schema=schema, header=True, multiLine=True, escape='"')

# %%
df_user.show()
# Out:
# +-------+-------+--------+
# |user_id|item_id|purchase|
# +-------+-------+--------+
# |   1654|  74107|       0|
# |   1654|  89249|       0|
# |   1654|  99982|       0|
# |   1654|  89901|       0|
# |   1654| 100504|       0|
# |   1654|  66187|       0|
# |   1654|  84350|       0|
# |   1654|  92854|       0|
# |   1654|  72811|       0|
# |   1654|  86876|       0|
# |   1654| 102657|       0|
# |   1654| 100482|       0|
# |   1654|  89677|       0|
# |   1654|  99419|       0|
# |   1654|  66603|       0|
# |   1654|   7363|       0|
# |   1654|   1320|       0|
# |   1654|  88892|       0|
# |   1654|  66671|       0|
# |   1654|  75925|       0|
# +-------+-------+--------+
# only showing top 20 rows

# %% [markdown]
# # test

# %%
schema = StructType([
    StructField("user_id", IntegerType(), True),
    StructField("item_id", IntegerType(), True),
])

# %%
df_user_test = spark.read.csv("/labs/slaba03/laba03_test.csv", schema=schema, header=True, multiLine=True, escape='"')

# %%
df_user_test.show()
# Out:
# +-------+-------+
# |user_id|item_id|
# +-------+-------+
# |   1654|  94814|
# |   1654|  93629|
# |   1654|   9980|
# |   1654|  95099|
# |   1654|  11265|
# |   1654|  88896|
# |   1654|  67740|
# |   1654|  74271|
# |   1654|  99871|
# |   1654|  78570|
# |   1654|  71942|
# |   1654|  74367|
# |   1654|  98628|
# |   1654|  95887|
# |   1654|  77795|
# |   1654|  75152|
# |   1654|  74905|
# |   1654|   9068|
# |   1654|  72954|
# |   1654| 102431|
# +-------+-------+
# only showing top 20 rows

# %% [markdown]
# # items

# %%
items_schema = StructType([
    StructField("item_id", IntegerType()),
    StructField("channel_id", IntegerType()),
    StructField("datetime_availability_start", StringType()),
    StructField("datetime_availability_stop", StringType()),
    StructField("datetime_show_start", StringType()),
    StructField("datetime_show_stop", StringType()),
    StructField("content_type", IntegerType()),
    StructField("title", StringType(), nullable=True),
    StructField("year", FloatType(), nullable=True),
    StructField("genres", StringType()),
    StructField("region_id", IntegerType()),
])

# %%
df_items = spark.read.option('delimiter', '\t').csv("/labs/slaba03/laba03_items.csv", header=True, schema=items_schema, multiLine=True, escape='"')

# %%
df_items.show()
# Out:
# +-------+----------+---------------------------+--------------------------+-------------------+------------------+------------+--------------------+------+--------------------+---------+
# |item_id|channel_id|datetime_availability_start|datetime_availability_stop|datetime_show_start|datetime_show_stop|content_type|               title|  year|              genres|region_id|
# +-------+----------+---------------------------+--------------------------+-------------------+------------------+------------+--------------------+------+--------------------+---------+
# |  65667|      null|       1970-01-01T00:00:00Z|      2018-01-01T00:00:00Z|               null|              null|           1|на пробах только ...|2013.0|             Эротика|     null|
# |  65669|      null|       1970-01-01T00:00:00Z|      2018-01-01T00:00:00Z|               null|              null|           1|скуби ду: эротиче...|2011.0|             Эротика|     null|
# |  65668|      null|       1970-01-01T00:00:00Z|      2018-01-01T00:00:00Z|               null|              null|           1|горячие девочки д...|2011.0|             Эротика|     null|
# |  65671|      null|       1970-01-01T00:00:00Z|      2018-01-01T00:00:00Z|               null|              null|           1|соблазнительницы ...|2011.0|             Эротика|     null|
# |  65670|      null|       1970-01-01T00:00:00Z|      2018-01-01T00:00:00Z|               null|              null|           1|секретные секс-ма...|2010.0|             Эротика|     null|
# |  65809|      null|       1970-01-01T00:00:00Z|      2099-12-31T21:00:00Z|               null|              null|           1|      все о мужчинах|2016.0|             Комедии|     null|
# |  65810|      null|       1970-01-01T00:00:00Z|      2099-12-31T21:00:00Z|               null|              null|           1|8 лучших свиданий...|2016.0|   Комедии,Мелодрамы|     null|
# |    326|      null|       1970-01-01T00:00:00Z|      2099-12-31T21:00:00Z|               null|              null|           1|            византия|2012.0|Ужасы,Триллеры,Др...|     null|
# |    336|      null|       1970-01-01T00:00:00Z|      2099-12-31T21:00:00Z|               null|              null|           1|девственники, бер...|2012.0|Ужасы,Комедии,Фан...|     null|
# |    357|      null|       1970-01-01T00:00:00Z|      2099-12-31T21:00:00Z|               null|              null|           1|   8 первых свиданий|2012.0|Комедии,Мелодрамы...|     null|
# |    396|      null|       1970-01-01T00:00:00Z|      2099-12-31T21:00:00Z|               null|              null|           1|        предчувствие|2007.0|Детективы,Триллер...|     null|
# |    400|      null|       1970-01-01T00:00:00Z|      2099-12-31T21:00:00Z|               null|              null|           1|          путь воина|2010.0|Фантастика,Боевик...|     null|
# |    423|      null|       1970-01-01T00:00:00Z|      2099-12-31T21:00:00Z|               null|              null|           1|    список контактов|2008.0|Детективы,Триллер...|     null|
# |    430|      null|       1970-01-01T00:00:00Z|      2099-12-31T21:00:00Z|               null|              null|           1|               сыщик|2007.0|Детективы,Триллер...|     null|
# |    449|      null|       1970-01-01T00:00:00Z|      2099-12-31T21:00:00Z|               null|              null|           1|             туристы|2006.0|Ужасы,Детективы,Т...|     null|
# |    453|      null|       1970-01-01T00:00:00Z|      2099-12-31T21:00:00Z|               null|              null|           1|      уроки вождения|2006.0|Комедии,Драмы,Зар...|     null|
# |    478|      null|       1970-01-01T00:00:00Z|      2099-12-31T21:00:00Z|               null|              null|           1|             апостол|2008.0|Военные,Боевики,Наши|     null|
# |    495|      null|       1970-01-01T00:00:00Z|      2099-12-31T21:00:00Z|               null|              null|           1|     железный рыцарь|2010.0|Приключения,Истор...|     null|
# |    505|      null|       1970-01-01T00:00:00Z|      2099-12-31T21:00:00Z|               null|              null|           1|че: часть первая....|2008.0|Военные,Драмы,Ист...|     null|
# |    540|      null|       1970-01-01T00:00:00Z|      2099-12-31T21:00:00Z|               null|              null|           1|   мой парень – псих|2012.0|Комедии,Драмы,Мел...|     null|
# +-------+----------+---------------------------+--------------------------+-------------------+------------------+------------+--------------------+------+--------------------+---------+
# only showing top 20 rows

# %%
df_items = df_items.filter(F.col("content_type") == 1)
df_items = df_items.select(F.regexp_replace('title', r',|\.|&|\\|\||–|_|:|-|\!|\?', '').alias('title'), 'item_id', 'year', 'genres')

# %%
from pyspark.sql.functions import split, when, array
df_items2 = df_items.withColumn("genres_word", split("genres", ","))
df_items2  = df_items2.withColumn('genres_word', when(df_items2['genres_word'].isNull(), array().cast("array<integer>")).otherwise(df_items2['genres_word']))

# %%
df_items2.show()
# Out:
# +--------------------+-------+------+--------------------+--------------------+
# |               title|item_id|  year|              genres|         genres_word|
# +--------------------+-------+------+--------------------+--------------------+
# |на пробах только ...|  65667|2013.0|             Эротика|           [Эротика]|
# |скуби ду эротичес...|  65669|2011.0|             Эротика|           [Эротика]|
# |горячие девочки д...|  65668|2011.0|             Эротика|           [Эротика]|
# |соблазнительницы ...|  65671|2011.0|             Эротика|           [Эротика]|
# |секретные сексмат...|  65670|2010.0|             Эротика|           [Эротика]|
# |      все о мужчинах|  65809|2016.0|             Комедии|           [Комедии]|
# |8 лучших свиданий...|  65810|2016.0|   Комедии,Мелодрамы|[Комедии, Мелодрамы]|
# |            византия|    326|2012.0|Ужасы,Триллеры,Др...|[Ужасы, Триллеры,...|
# |девственники бере...|    336|2012.0|Ужасы,Комедии,Фан...|[Ужасы, Комедии, ...|
# |   8 первых свиданий|    357|2012.0|Комедии,Мелодрамы...|[Комедии, Мелодра...|
# |        предчувствие|    396|2007.0|Детективы,Триллер...|[Детективы, Трилл...|
# |          путь воина|    400|2010.0|Фантастика,Боевик...|[Фантастика, Боев...|
# |    список контактов|    423|2008.0|Детективы,Триллер...|[Детективы, Трилл...|
# |               сыщик|    430|2007.0|Детективы,Триллер...|[Детективы, Трилл...|
# |             туристы|    449|2006.0|Ужасы,Детективы,Т...|[Ужасы, Детективы...|
# |      уроки вождения|    453|2006.0|Комедии,Драмы,Зар...|[Комедии, Драмы, ...|
# |             апостол|    478|2008.0|Военные,Боевики,Наши|[Военные, Боевики...|
# |     железный рыцарь|    495|2010.0|Приключения,Истор...|[Приключения, Ист...|
# |че часть первая а...|    505|2008.0|Военные,Драмы,Ист...|[Военные, Драмы, ...|
# |    мой парень  псих|    540|2012.0|Комедии,Драмы,Мел...|[Комедии, Драмы, ...|
# +--------------------+-------+------+--------------------+--------------------+
# only showing top 20 rows

# %%
stop_words = StopWordsRemover.loadDefaultStopWords("russian")  
tokenizer = Tokenizer(inputCol="title", outputCol="title_words")
swr = StopWordsRemover(inputCol=tokenizer.getOutputCol(), outputCol="title_words_filtered", stopWords=stop_words)
#count_vectorizer = CountVectorizer(inputCol=swr.getOutputCol(), outputCol="word_vector", vocabSize=10000)
#tfidf = IDF(inputCol="word_vector", outputCol="tfidf")    

hasher = HashingTF(numFeatures=200, binary=True, inputCol=swr.getOutputCol(), outputCol="word_vector")


preprocessing = Pipeline(stages=[
        tokenizer,
        swr,
        #count_vectorizer,
        #tfidf
        hasher
    ])
    
preprocessing_model = preprocessing.fit(df_items2)
df_items3 = preprocessing_model.transform(df_items2)

# %%
df_items3.show(2, vertical=True)
# Out:
# -RECORD 0------------------------------------
#  title                | на пробах только ...
#  item_id              | 65667
#  year                 | 2013.0
#  genres               | Эротика
#  genres_word          | [Эротика]
#  title_words          | [на, пробах, толь...
#  title_words_filtered | [пробах, девушки,...
#  word_vector          | (200,[0,4,23,29,8...
# -RECORD 1------------------------------------
#  title                | скуби ду эротичес...
#  item_id              | 65669
#  year                 | 2011.0
#  genres               | Эротика
#  genres_word          | [Эротика]
#  title_words          | [скуби, ду, эроти...
#  title_words_filtered | [скуби, ду, эроти...
#  word_vector          | (200,[17,33,99,10...
# only showing top 2 rows

# %%
count_vectorizer = CountVectorizer(inputCol='genres_word', outputCol='genre_vector')
items = count_vectorizer.fit(df_items3).transform(df_items3)

# %%
items.show()
# Out:
# +--------------------+-------+------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+
# |               title|item_id|  year|              genres|         genres_word|         title_words|title_words_filtered|         word_vector|        genre_vector|
# +--------------------+-------+------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+
# |на пробах только ...|  65667|2013.0|             Эротика|           [Эротика]|[на, пробах, толь...|[пробах, девушки,...|(200,[0,4,23,29,8...|     (83,[20],[1.0])|
# |скуби ду эротичес...|  65669|2011.0|             Эротика|           [Эротика]|[скуби, ду, эроти...|[скуби, ду, эроти...|(200,[17,33,99,10...|     (83,[20],[1.0])|
# |горячие девочки д...|  65668|2011.0|             Эротика|           [Эротика]|[горячие, девочки...|[горячие, девочки...|(200,[31,51,67,93...|     (83,[20],[1.0])|
# |соблазнительницы ...|  65671|2011.0|             Эротика|           [Эротика]|[соблазнительницы...|[соблазнительницы...|(200,[66,131,153,...|     (83,[20],[1.0])|
# |секретные сексмат...|  65670|2010.0|             Эротика|           [Эротика]|[секретные, сексм...|[секретные, сексм...|(200,[49,52,63,66...|     (83,[20],[1.0])|
# |      все о мужчинах|  65809|2016.0|             Комедии|           [Комедии]|  [все, о, мужчинах]|          [мужчинах]|   (200,[146],[1.0])|      (83,[2],[1.0])|
# |8 лучших свиданий...|  65810|2016.0|   Комедии,Мелодрамы|[Комедии, Мелодрамы]|[8, лучших, свида...|[8, лучших, свида...|(200,[26,160,180,...|(83,[2,7],[1.0,1.0])|
# |            византия|    326|2012.0|Ужасы,Триллеры,Др...|[Ужасы, Триллеры,...|          [византия]|          [византия]|   (200,[137],[1.0])|(83,[0,1,3,10,12]...|
# |девственники бере...|    336|2012.0|Ужасы,Комедии,Фан...|[Ужасы, Комедии, ...|[девственники, бе...|[девственники, бе...|(200,[143,190],[1...|(83,[0,2,10,12],[...|
# |   8 первых свиданий|    357|2012.0|Комедии,Мелодрамы...|[Комедии, Мелодра...|[8, первых, свида...|[8, первых, свида...|(200,[26,82,180],...|(83,[2,6,7],[1.0,...|
# |        предчувствие|    396|2007.0|Детективы,Триллер...|[Детективы, Трилл...|      [предчувствие]|      [предчувствие]|   (200,[138],[1.0])|(83,[0,1,3,11,12]...|
# |          путь воина|    400|2010.0|Фантастика,Боевик...|[Фантастика, Боев...|       [путь, воина]|       [путь, воина]|(200,[142,183],[1...|(83,[0,5,12],[1.0...|
# |    список контактов|    423|2008.0|Детективы,Триллер...|[Детективы, Трилл...| [список, контактов]| [список, контактов]|(200,[0,163],[1.0...|(83,[0,1,3,11,13]...|
# |               сыщик|    430|2007.0|Детективы,Триллер...|[Детективы, Трилл...|             [сыщик]|             [сыщик]|    (200,[73],[1.0])|(83,[0,1,3,11],[1...|
# |             туристы|    449|2006.0|Ужасы,Детективы,Т...|[Ужасы, Детективы...|           [туристы]|           [туристы]|   (200,[110],[1.0])|(83,[0,3,10,11],[...|
# |      уроки вождения|    453|2006.0|Комедии,Драмы,Зар...|[Комедии, Драмы, ...|   [уроки, вождения]|   [уроки, вождения]|(200,[21,147],[1....|(83,[0,1,2],[1.0,...|
# |             апостол|    478|2008.0|Военные,Боевики,Наши|[Военные, Боевики...|           [апостол]|           [апостол]|    (200,[67],[1.0])|(83,[5,6,16],[1.0...|
# |     железный рыцарь|    495|2010.0|Приключения,Истор...|[Приключения, Ист...|  [железный, рыцарь]|  [железный, рыцарь]|(200,[88,177],[1....|(83,[0,5,7,8,25],...|
# |че часть первая а...|    505|2008.0|Военные,Драмы,Ист...|[Военные, Драмы, ...|[че, часть, перва...|[че, часть, перва...|(200,[14,34,122],...|(83,[0,1,16,25],[...|
# |    мой парень  псих|    540|2012.0|Комедии,Драмы,Мел...|[Комедии, Драмы, ...|[мой, парень, , п...|    [парень, , псих]|(200,[44,164,172]...|(83,[0,1,2,7],[1....|
# +--------------------+-------+------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+
# only showing top 20 rows

# %% [markdown]
# # обьединяем train и items

# %%
df_train = df_user.join(items, on="item_id", how="inner")

# %%
df_train.show(2,vertical=True)
# Out:
# -RECORD 0------------------------------------
#  item_id              | 8389
#  user_id              | 520446
#  purchase             | 0
#  title                | пес в сапогах (су...
#  year                 | 1981.0
#  genres               | Мультфильмы,Детск...
#  genres_word          | [Мультфильмы, Дет...
#  title_words          | [пес, в, сапогах,...
#  title_words_filtered | [пес, сапогах, (с...
#  word_vector          | (200,[58,84,187],...
#  genre_vector         | (83,[6,14,19,23],...
# -RECORD 1------------------------------------
#  item_id              | 8389
#  user_id              | 556825
#  purchase             | 0
#  title                | пес в сапогах (су...
#  year                 | 1981.0
#  genres               | Мультфильмы,Детск...
#  genres_word          | [Мультфильмы, Дет...
#  title_words          | [пес, в, сапогах,...
#  title_words_filtered | [пес, сапогах, (с...
#  word_vector          | (200,[58,84,187],...
#  genre_vector         | (83,[6,14,19,23],...
# only showing top 2 rows

# %%
test = df_user_test.join(items, on="item_id", how="inner")

# %%
test.show(2,vertical=True)
# Out:
# -RECORD 0------------------------------------
#  item_id              | 8389
#  user_id              | 1654
#  title                | пес в сапогах (су...
#  year                 | 1981.0
#  genres               | Мультфильмы,Детск...
#  genres_word          | [Мультфильмы, Дет...
#  title_words          | [пес, в, сапогах,...
#  title_words_filtered | [пес, сапогах, (с...
#  word_vector          | (200,[58,84,187],...
#  genre_vector         | (83,[6,14,19,23],...
# -RECORD 1------------------------------------
#  item_id              | 8389
#  user_id              | 510087
#  title                | пес в сапогах (су...
#  year                 | 1981.0
#  genres               | Мультфильмы,Детск...
#  genres_word          | [Мультфильмы, Дет...
#  title_words          | [пес, в, сапогах,...
#  title_words_filtered | [пес, сапогах, (с...
#  word_vector          | (200,[58,84,187],...
#  genre_vector         | (83,[6,14,19,23],...
# only showing top 2 rows

# %% [markdown]
# ## фичи

# %%
#df_val = df_train.where(df_train.year<2020)

# %%
df_val2 = df_train.groupby(F.col('item_id')).agg(F.mean('purchase').alias("item_mean_encoding"))

# %%
df_val3 = df_train.groupby(F.col('user_id')).agg(F.mean('purchase').alias("intensity_user"))

# %%
df_val3.show()
# Out:
# +-------+--------------------+
# |user_id|      intensity_user|
# +-------+--------------------+
# | 754230|0.027575641516660282|
# | 761341|3.875968992248062E-4|
# | 776188|0.001152516327314637|
# | 780033|7.757951900698216E-4|
# | 798454|3.840245775729646...|
# | 825061|0.001931247585940...|
# | 833685|0.007500986971969996|
# | 846231|0.001923816852635629|
# | 851486|                 0.0|
# | 867850|3.829950210647261...|
# | 870928|7.674597083653108E-4|
# | 879401|0.004283489096573208|
# | 901457|                 0.0|
# | 927211|3.916960438699569E-4|
# | 928140|3.869969040247678E-4|
# | 793876|0.001940240589833...|
# | 795620|0.004243827160493827|
# | 822709|3.789314134141720...|
# | 824008|3.821169277799006...|
# | 851848|3.888024883359253...|
# +-------+--------------------+
# only showing top 20 rows

# %%
df_train2 = df_train.join(df_val2, on="item_id", how="left")

# %%
df_train3 = df_train2.join(df_val3, on="user_id", how="left")

# %%
df_train3.show()
# Out:
# +-------+-------+--------+--------------------+------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+
# |user_id|item_id|purchase|               title|  year|              genres|         genres_word|         title_words|title_words_filtered|         word_vector|        genre_vector|  item_mean_encoding|      intensity_user|
# +-------+-------+--------+--------------------+------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+
# | 754230|   8389|       0|пес в сапогах (су...|1981.0|Мультфильмы,Детск...|[Мультфильмы, Дет...|[пес, в, сапогах,...|[пес, сапогах, (с...|(200,[58,84,187],...|(83,[6,14,19,23],...|0.005979073243647235|0.027575641516660282|
# | 754230|   8638|       1| охотники на демонов|2012.0|Ужасы,Комедии,Три...|[Ужасы, Комедии, ...|[охотники, на, де...| [охотники, демонов]|(200,[36,97],[1.0...|(83,[0,2,3,10,35]...|0.001450326323422...|0.027575641516660282|
# | 754230|  10817|       0|норвегия дикая пр...|2013.0|Документальные,За...|[Документальные, ...|[норвегия, дикая,...|[норвегия, дикая,...|(200,[50,79,161],...|(83,[0,27],[1.0,1...|7.380073800738007E-4|0.027575641516660282|
# | 754230|  72820|       0|           джульетта|2016.0|Драмы,Мелодрамы,З...|[Драмы, Мелодрамы...|         [джульетта]|         [джульетта]|   (200,[147],[1.0])|(83,[0,1,7],[1.0,...|7.390983000739098E-4|0.027575641516660282|
# | 754230|  74757|       0|        мертвые души|2012.0|Мистические,Ужасы...|[Мистические, Ужа...|     [мертвые, души]|     [мертвые, души]|(200,[21,57],[1.0...|(83,[0,10,30],[1....|7.358351729212656E-4|0.027575641516660282|
# | 754230|  74820|       0|пираты эгейского ...|2012.0|Приключения,Истор...|[Приключения, Ист...|[пираты, эгейског...|[пираты, эгейског...|(200,[35,57,152],...|(83,[0,8,25,36],[...| 7.44047619047619E-4|0.027575641516660282|
# | 754230|  78113|       0|       на белом коне|2016.0|Комедии,Мелодрамы...|[Комедии, Мелодра...|   [на, белом, коне]|       [белом, коне]|(200,[88,146],[1....|(83,[2,4,7,15],[1...|0.001468428781204...|0.027575641516660282|
# | 754230|  90019|       0|                гнев|2014.0|Детективы,Триллер...|[Детективы, Трилл...|              [гнев]|              [гнев]|   (200,[145],[1.0])|(83,[0,3,5,11],[1...|0.002281368821292...|0.027575641516660282|
# | 754230|  94851|       0|отчаянная домохоз...|2010.0|  Комедии,Зарубежные|[Комедии, Зарубеж...|[отчаянная, домох...|[отчаянная, домох...|(200,[90,112],[1....|(83,[0,2],[1.0,1.0])|7.288629737609329E-4|0.027575641516660282|
# | 754230|  95080|       0|               шакал|2016.0|           Детективы|         [Детективы]|             [шакал]|             [шакал]|   (200,[155],[1.0])|     (83,[11],[1.0])|                 0.0|0.027575641516660282|
# | 754230|  95940|       0|                лимб|2013.0|Ужасы,Детективы,Т...|[Ужасы, Детективы...|              [лимб]|              [лимб]|   (200,[112],[1.0])|(83,[0,3,10,11],[...|   7.097232079489E-4|0.027575641516660282|
# | 754230|  99817|       0|     маугли (сериал)|1967.0|Русские мультфиль...|[Русские мультфил...|  [маугли, (сериал)]|  [маугли, (сериал)]|(200,[69,186],[1....|(83,[4,9,17,21],[...|                 0.0|0.027575641516660282|
# | 754230|    540|       0|    мой парень  псих|2012.0|Комедии,Драмы,Мел...|[Комедии, Драмы, ...|[мой, парень, , п...|    [парень, , псих]|(200,[44,164,172]...|(83,[0,1,2,7],[1....| 7.23589001447178E-4|0.027575641516660282|
# | 754230|   1522|       0|     патруль времени|1994.0|Триллеры,Фантасти...|[Триллеры, Фантас...|  [патруль, времени]|  [патруль, времени]|(200,[68,128],[1....|(83,[0,3,5,7,12],...|7.507507507507507E-4|0.027575641516660282|
# | 754230|   2999|       0|   блондинка в эфире|2014.0|Приключения,Комед...|[Приключения, Ком...|[блондинка, в, эф...|  [блондинка, эфире]|(200,[19,70],[1.0...|(83,[0,2,8],[1.0,...|0.003644314868804...|0.027575641516660282|
# | 754230|  10914|       0|             фазенда|2012.0|      Познавательные|    [Познавательные]|           [фазенда]|           [фазенда]|   (200,[140],[1.0])|     (83,[33],[1.0])|7.320644216691069E-4|0.027575641516660282|
# | 754230|  68609|       0|       полной грудью|2013.0|Драмы,Мелодрамы,З...|[Драмы, Мелодрамы...|    [полной, грудью]|    [полной, грудью]|(200,[79,186],[1....|(83,[0,1,7],[1.0,...|0.002188183807439825|0.027575641516660282|
# | 754230|  76701|       0|как утёнокмузыкан...|1978.0| Советские,Для детей|[Советские, Для д...|[как, утёнокмузык...|[утёнокмузыкант, ...|(200,[14,36,77],[...|(83,[9,21],[1.0,1...| 7.23589001447178E-4|0.027575641516660282|
# | 754230|  78272|       0|     люблю твою жену|2013.0|Комедии,Мелодрамы...|[Комедии, Мелодра...| [люблю, твою, жену]| [люблю, твою, жену]|(200,[21,34,132],...|(83,[0,2,7],[1.0,...|0.002169197396963...|0.027575641516660282|
# | 754230|  90493|       0|навигатор игровог...|2016.0|Развлекательные,В...|[Развлекательные,...|[навигатор, игров...|[навигатор, игров...|(200,[4,57,152,18...|(83,[4,33,40,45],...|                 0.0|0.027575641516660282|
# +-------+-------+--------+--------------------+------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+
# only showing top 20 rows

# %%
test = test.join(df_val2, on="item_id", how="left")

# %%
test = test.join(df_val3, on="user_id", how="left")

# %%
test.show(2,vertical=True)
# Out:
# -RECORD 0------------------------------------
#  user_id              | 754230
#  item_id              | 73041
#  title                | коко до шанель
#  year                 | 2009.0
#  genres               | Драмы,Исторически...
#  genres_word          | [Драмы, Историчес...
#  title_words          | [коко, до, шанель]
#  title_words_filtered | [коко, шанель]
#  word_vector          | (200,[63,108],[1....
#  genre_vector         | (83,[0,1,25],[1.0...
#  item_mean_encoding   | 7.352941176470588E-4
#  intensity_user       | 0.027575641516660282
# -RECORD 1------------------------------------
#  user_id              | 754230
#  item_id              | 74440
#  title                | области тьмы
#  year                 | 2011.0
#  genres               | Детективы,Фантаст...
#  genres_word          | [Детективы, Фанта...
#  title_words          | [области, тьмы]
#  title_words_filtered | [области, тьмы]
#  word_vector          | (200,[79,152],[1....
#  genre_vector         | (83,[0,11,12],[1....
#  item_mean_encoding   | 0.00363901018922853
#  intensity_user       | 0.027575641516660282
# only showing top 2 rows

# %%
df_train3 = df_train3.na.fill(0)

# %%
test = test.na.fill(0)

# %% [markdown]
# # обьединение фичей

# %%
from pyspark.ml.feature import VectorAssembler

# %%
assembler = VectorAssembler(inputCols=['user_id','item_id','item_mean_encoding', 'intensity_user'], outputCol="features")

# %%
df_train = assembler.transform(df_train3)

# %%
df_train.show()
# Out:
# +-------+-------+--------+--------------------+------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+
# |user_id|item_id|purchase|               title|  year|              genres|         genres_word|         title_words|title_words_filtered|         word_vector|        genre_vector|  item_mean_encoding|      intensity_user|            features|
# +-------+-------+--------+--------------------+------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+
# | 754230|   8389|       0|пес в сапогах (су...|1981.0|Мультфильмы,Детск...|[Мультфильмы, Дет...|[пес, в, сапогах,...|[пес, сапогах, (с...|(200,[58,84,187],...|(83,[6,14,19,23],...|0.005979073243647235|0.027575641516660282|[754230.0,8389.0,...|
# | 754230|   8638|       1| охотники на демонов|2012.0|Ужасы,Комедии,Три...|[Ужасы, Комедии, ...|[охотники, на, де...| [охотники, демонов]|(200,[36,97],[1.0...|(83,[0,2,3,10,35]...|0.001450326323422...|0.027575641516660282|[754230.0,8638.0,...|
# | 754230|  10817|       0|норвегия дикая пр...|2013.0|Документальные,За...|[Документальные, ...|[норвегия, дикая,...|[норвегия, дикая,...|(200,[50,79,161],...|(83,[0,27],[1.0,1...|7.380073800738007E-4|0.027575641516660282|[754230.0,10817.0...|
# | 754230|  72820|       0|           джульетта|2016.0|Драмы,Мелодрамы,З...|[Драмы, Мелодрамы...|         [джульетта]|         [джульетта]|   (200,[147],[1.0])|(83,[0,1,7],[1.0,...|7.390983000739098E-4|0.027575641516660282|[754230.0,72820.0...|
# | 754230|  74757|       0|        мертвые души|2012.0|Мистические,Ужасы...|[Мистические, Ужа...|     [мертвые, души]|     [мертвые, души]|(200,[21,57],[1.0...|(83,[0,10,30],[1....|7.358351729212656E-4|0.027575641516660282|[754230.0,74757.0...|
# | 754230|  74820|       0|пираты эгейского ...|2012.0|Приключения,Истор...|[Приключения, Ист...|[пираты, эгейског...|[пираты, эгейског...|(200,[35,57,152],...|(83,[0,8,25,36],[...| 7.44047619047619E-4|0.027575641516660282|[754230.0,74820.0...|
# | 754230|  78113|       0|       на белом коне|2016.0|Комедии,Мелодрамы...|[Комедии, Мелодра...|   [на, белом, коне]|       [белом, коне]|(200,[88,146],[1....|(83,[2,4,7,15],[1...|0.001468428781204...|0.027575641516660282|[754230.0,78113.0...|
# | 754230|  90019|       0|                гнев|2014.0|Детективы,Триллер...|[Детективы, Трилл...|              [гнев]|              [гнев]|   (200,[145],[1.0])|(83,[0,3,5,11],[1...|0.002281368821292...|0.027575641516660282|[754230.0,90019.0...|
# | 754230|  94851|       0|отчаянная домохоз...|2010.0|  Комедии,Зарубежные|[Комедии, Зарубеж...|[отчаянная, домох...|[отчаянная, домох...|(200,[90,112],[1....|(83,[0,2],[1.0,1.0])|7.288629737609329E-4|0.027575641516660282|[754230.0,94851.0...|
# | 754230|  95080|       0|               шакал|2016.0|           Детективы|         [Детективы]|             [шакал]|             [шакал]|   (200,[155],[1.0])|     (83,[11],[1.0])|                 0.0|0.027575641516660282|[754230.0,95080.0...|
# | 754230|  95940|       0|                лимб|2013.0|Ужасы,Детективы,Т...|[Ужасы, Детективы...|              [лимб]|              [лимб]|   (200,[112],[1.0])|(83,[0,3,10,11],[...|   7.097232079489E-4|0.027575641516660282|[754230.0,95940.0...|
# | 754230|  99817|       0|     маугли (сериал)|1967.0|Русские мультфиль...|[Русские мультфил...|  [маугли, (сериал)]|  [маугли, (сериал)]|(200,[69,186],[1....|(83,[4,9,17,21],[...|                 0.0|0.027575641516660282|[754230.0,99817.0...|
# | 754230|   7098|       0|    цветиксемицветик|1948.0|Мультфильмы,Детск...|[Мультфильмы, Дет...|  [цветиксемицветик]|  [цветиксемицветик]|    (200,[54],[1.0])|(83,[6,14,19,23],...|                 0.0|0.027575641516660282|[754230.0,7098.0,...|
# | 754230|   7644|       0|самый маленький гном|1977.0|Мультфильмы,Детск...|[Мультфильмы, Дет...|[самый, маленький...|[самый, маленький...|(200,[10,129,168]...|(83,[6,14,19,23],...|0.001472754050073...|0.027575641516660282|[754230.0,7644.0,...|
# | 754230|  65879|       0|книга илая (сурдо...|2009.0|Триллеры,Боевики,...|[Триллеры, Боевик...|[книга, илая, (су...|[книга, илая, (су...|(200,[44,141,187]...|(83,[0,3,5],[1.0,...|0.005124450951683748|0.027575641516660282|[754230.0,65879.0...|
# | 754230|  66594|       0|              экипаж|2016.0|Приключения,Трилл...|[Приключения, Три...|            [экипаж]|            [экипаж]|   (200,[105],[1.0])|(83,[1,3,8],[1.0,...| 0.01581325301204819|0.027575641516660282|[754230.0,66594.0...|
# | 754230|  74318|       0|      падение олимпа|2013.0|Триллеры,Боевики,...|[Триллеры, Боевик...|   [падение, олимпа]|   [падение, олимпа]|(200,[71,93],[1.0...|(83,[0,3,5],[1.0,...|0.003717472118959...|0.027575641516660282|[754230.0,74318.0...|
# | 754230|  81832|       0|        неупокоенная|2014.0|Мистические,Ужасы...|[Мистические, Ужа...|      [неупокоенная]|      [неупокоенная]|   (200,[173],[1.0])|(83,[0,3,10,30],[...|7.429420505200594E-4|0.027575641516660282|[754230.0,81832.0...|
# | 754230|  91200|       0|не входить мы не ...|2012.0|Комедии,Драмы,Мел...|[Комедии, Драмы, ...|[не, входить, мы,...|    [входить, одеты]|(200,[42,109],[1....|(83,[0,1,2,7],[1....|7.358351729212656E-4|0.027575641516660282|[754230.0,91200.0...|
# | 754230|  94722|       0| приключения мышонка|2013.0|Полнометражные,Дл...|[Полнометражные, ...|[приключения, мыш...|[приключения, мыш...|(200,[76,143],[1....|(83,[0,9,18],[1.0...|                 0.0|0.027575641516660282|[754230.0,94722.0...|
# +-------+-------+--------+--------------------+------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+
# only showing top 20 rows

# %%
test = assembler.transform(test)

# %%
test.show(vertical=True)
# Out:
# -RECORD 0------------------------------------
#  user_id              | 754230
#  item_id              | 93486
#  title                | виноградник
#  year                 | 2014.0
#  genres               | Триллеры,Фантастика
#  genres_word          | [Триллеры, Фантас...
#  title_words          | [виноградник]
#  title_words_filtered | [виноградник]
#  word_vector          | (200,[33],[1.0])
#  genre_vector         | (83,[3,12],[1.0,1...
#  item_mean_encoding   | 0.002141327623126...
#  intensity_user       | 0.027575641516660282
#  features             | [754230.0,93486.0...
# -RECORD 1------------------------------------
#  user_id              | 754230
#  item_id              | 94819
#  title                | невидимый мир
#  year                 | 2011.0
#  genres               | Драмы,Зарубежные
#  genres_word          | [Драмы, Зарубежные]
#  title_words          | [невидимый, мир]
#  title_words_filtered | [невидимый, мир]
#  word_vector          | (200,[26,100],[1....
#  genre_vector         | (83,[0,1],[1.0,1.0])
#  item_mean_encoding   | 7.163323782234957E-4
#  intensity_user       | 0.027575641516660282
#  features             | [754230.0,94819.0...
# -RECORD 2------------------------------------
#  user_id              | 754230
#  item_id              | 73041
#  title                | коко до шанель
#  year                 | 2009.0
#  genres               | Драмы,Исторически...
#  genres_word          | [Драмы, Историчес...
#  title_words          | [коко, до, шанель]
#  title_words_filtered | [коко, шанель]
#  word_vector          | (200,[63,108],[1....
#  genre_vector         | (83,[0,1,25],[1.0...
#  item_mean_encoding   | 7.352941176470588E-4
#  intensity_user       | 0.027575641516660282
#  features             | [754230.0,73041.0...
# -RECORD 3------------------------------------
#  user_id              | 754230
#  item_id              | 74440
#  title                | области тьмы
#  year                 | 2011.0
#  genres               | Детективы,Фантаст...
#  genres_word          | [Детективы, Фанта...
#  title_words          | [области, тьмы]
#  title_words_filtered | [области, тьмы]
#  word_vector          | (200,[79,152],[1....
#  genre_vector         | (83,[0,11,12],[1....
#  item_mean_encoding   | 0.00363901018922853
#  intensity_user       | 0.027575641516660282
#  features             | [754230.0,74440.0...
# -RECORD 4------------------------------------
#  user_id              | 754230
#  item_id              | 74452
#  title                | я плюю на ваши мо...
#  year                 | 2013.0
#  genres               | Ужасы,Триллеры,Кр...
#  genres_word          | [Ужасы, Триллеры,...
#  title_words          | [я, плюю, на, ваш...
#  title_words_filtered | [плюю, ваши, моги...
#  word_vector          | (200,[93,123,175]...
#  genre_vector         | (83,[0,3,10,13],[...
#  item_mean_encoding   | 0.001488095238095238
#  intensity_user       | 0.027575641516660282
#  features             | [754230.0,74452.0...
# -RECORD 5------------------------------------
#  user_id              | 754230
#  item_id              | 93131
#  title                | навигатор игровог...
#  year                 | 2015.0
#  genres               | Развлекательные,В...
#  genres_word          | [Развлекательные,...
#  title_words          | [навигатор, игров...
#  title_words_filtered | [навигатор, игров...
#  word_vector          | (200,[57,152,181,...
#  genre_vector         | (83,[4,33,40,45],...
#  item_mean_encoding   | 7.293946024799417E-4
#  intensity_user       | 0.027575641516660282
#  features             | [754230.0,93131.0...
# -RECORD 6------------------------------------
#  user_id              | 754230
#  item_id              | 93633
#  title                | три богатыря на д...
#  year                 | 2012.0
#  genres               | Приключения,Комед...
#  genres_word          | [Приключения, Ком...
#  title_words          | [три, богатыря, н...
#  title_words_filtered | [богатыря, дальни...
#  word_vector          | (200,[21,106,169,...
#  genre_vector         | (83,[2,8,12],[1.0...
#  item_mean_encoding   | 0.002212389380530...
#  intensity_user       | 0.027575641516660282
#  features             | [754230.0,93633.0...
# -RECORD 7------------------------------------
#  user_id              | 754230
#  item_id              | 95151
#  title                | невеста
#  year                 | 2017.0
#  genres               | Мистические,Ужасы...
#  genres_word          | [Мистические, Ужа...
#  title_words          | [невеста]
#  title_words_filtered | [невеста]
#  word_vector          | (200,[196],[1.0])
#  genre_vector         | (83,[3,4,10,30],[...
#  item_mean_encoding   | 0.001456664238892...
#  intensity_user       | 0.027575641516660282
#  features             | [754230.0,95151.0...
# -RECORD 8------------------------------------
#  user_id              | 754230
#  item_id              | 11025
#  title                | рэтчет и кланк га...
#  year                 | 2016.0
#  genres               | Приключения,Комед...
#  genres_word          | [Приключения, Ком...
#  title_words          | [рэтчет, и, кланк...
#  title_words_filtered | [рэтчет, кланк, г...
#  word_vector          | (200,[76,102,115,...
#  genre_vector         | (83,[0,2,5,8,12],...
#  item_mean_encoding   | 0.0
#  intensity_user       | 0.027575641516660282
#  features             | [754230.0,11025.0...
# -RECORD 9------------------------------------
#  user_id              | 754230
#  item_id              | 72912
#  title                | хорошо сидим
#  year                 | 1986.0
#  genres               | Комедии,Наши
#  genres_word          | [Комедии, Наши]
#  title_words          | [хорошо, сидим]
#  title_words_filtered | [сидим]
#  word_vector          | (200,[196],[1.0])
#  genre_vector         | (83,[2,6],[1.0,1.0])
#  item_mean_encoding   | 0.0
#  intensity_user       | 0.027575641516660282
#  features             | [754230.0,72912.0...
# -RECORD 10-----------------------------------
#  user_id              | 754230
#  item_id              | 86406
#  title                | стритрейсеры
#  year                 | 2008.0
#  genres               | Русские,Боевики
#  genres_word          | [Русские, Боевики]
#  title_words          | [стритрейсеры]
#  title_words_filtered | [стритрейсеры]
#  word_vector          | (200,[182],[1.0])
#  genre_vector         | (83,[4,5],[1.0,1.0])
#  item_mean_encoding   | 0.0
#  intensity_user       | 0.027575641516660282
#  features             | [754230.0,86406.0...
# -RECORD 11-----------------------------------
#  user_id              | 754230
#  item_id              | 88999
#  title                | пираньи 3dd
#  year                 | 2012.0
#  genres               | Ужасы,Комедии,Три...
#  genres_word          | [Ужасы, Комедии, ...
#  title_words          | [пираньи, 3dd]
#  title_words_filtered | [пираньи, 3dd]
#  word_vector          | (200,[112,143],[1...
#  genre_vector         | (83,[0,2,3,10],[1...
#  item_mean_encoding   | 0.004411764705882353
#  intensity_user       | 0.027575641516660282
#  features             | [754230.0,88999.0...
# -RECORD 12-----------------------------------
#  user_id              | 754230
#  item_id              | 93487
#  title                | инфекция фаза 2
#  year                 | 2015.0
#  genres               | Ужасы,Триллеры,Драмы
#  genres_word          | [Ужасы, Триллеры,...
#  title_words          | [инфекция, фаза, 2]
#  title_words_filtered | [инфекция, фаза, 2]
#  word_vector          | (200,[25,144,189]...
#  genre_vector         | (83,[1,3,10],[1.0...
#  item_mean_encoding   | 0.003023431594860...
#  intensity_user       | 0.027575641516660282
#  features             | [754230.0,93487.0...
# -RECORD 13-----------------------------------
#  user_id              | 754230
#  item_id              | 9071
#  title                | любовь в большом ...
#  year                 | 2009.0
#  genres               | Комедии,Фантастик...
#  genres_word          | [Комедии, Фантаст...
#  title_words          | [любовь, в, больш...
#  title_words_filtered | [любовь, большом,...
#  word_vector          | (200,[15,93,100],...
#  genre_vector         | (83,[2,6,7,12],[1...
#  item_mean_encoding   | 0.0
#  intensity_user       | 0.027575641516660282
#  features             | [754230.0,9071.0,...
# -RECORD 14-----------------------------------
#  user_id              | 754230
#  item_id              | 72387
#  title                | метод
#  year                 | 2015.0
#  genres               | Детективы,Драмы,Т...
#  genres_word          | [Детективы, Драмы...
#  title_words          | [метод]
#  title_words_filtered | [метод]
#  word_vector          | (200,[52],[1.0])
#  genre_vector         | (83,[1,3,4,11],[1...
#  item_mean_encoding   | 0.0
#  intensity_user       | 0.027575641516660282
#  features             | [754230.0,72387.0...
# -RECORD 15-----------------------------------
#  user_id              | 754230
#  item_id              | 78269
#  title                | секс  за деньги л...
#  year                 | 2011.0
#  genres               | Комедии,Зарубежные
#  genres_word          | [Комедии, Зарубеж...
#  title_words          | [секс, , за, день...
#  title_words_filtered | [секс, , деньги, ...
#  word_vector          | (200,[68,93,100,1...
#  genre_vector         | (83,[0,2],[1.0,1.0])
#  item_mean_encoding   | 0.0
#  intensity_user       | 0.027575641516660282
#  features             | [754230.0,78269.0...
# -RECORD 16-----------------------------------
#  user_id              | 754230
#  item_id              | 93477
#  title                | застава
#  year                 | 2007.0
#  genres               | Военные,Драмы
#  genres_word          | [Военные, Драмы]
#  title_words          | [застава]
#  title_words_filtered | [застава]
#  word_vector          | (200,[186],[1.0])
#  genre_vector         | (83,[1,16],[1.0,1...
#  item_mean_encoding   | 7.25689404934688E-4
#  intensity_user       | 0.027575641516660282
#  features             | [754230.0,93477.0...
# -RECORD 17-----------------------------------
#  user_id              | 754230
#  item_id              | 94726
#  title                | я прихожу с дождем
#  year                 | 2009.0
#  genres               | Триллеры,Драмы,За...
#  genres_word          | [Триллеры, Драмы,...
#  title_words          | [я, прихожу, с, д...
#  title_words_filtered | [прихожу, дождем]
#  word_vector          | (200,[150,151],[1...
#  genre_vector         | (83,[0,1,3],[1.0,...
#  item_mean_encoding   | 0.001490312965722...
#  intensity_user       | 0.027575641516660282
#  features             | [754230.0,94726.0...
# -RECORD 18-----------------------------------
#  user_id              | 754230
#  item_id              | 10788
#  title                | карибские острова...
#  year                 | 2012.0
#  genres               | Документальные,За...
#  genres_word          | [Документальные, ...
#  title_words          | [карибские, остро...
#  title_words_filtered | [карибские, остро...
#  word_vector          | (200,[32,39,144,1...
#  genre_vector         | (83,[0,27],[1.0,1...
#  item_mean_encoding   | 0.004347826086956522
#  intensity_user       | 0.027575641516660282
#  features             | [754230.0,10788.0...
# -RECORD 19-----------------------------------
#  user_id              | 754230
#  item_id              | 11520
#  title                | спасение
#  year                 | 2015.0
#  genres               | Триллеры,Боевики,...
#  genres_word          | [Триллеры, Боевик...
#  title_words          | [спасение]
#  title_words_filtered | [спасение]
#  word_vector          | (200,[2],[1.0])
#  genre_vector         | (83,[0,3,5],[1.0,...
#  item_mean_encoding   | 0.001457725947521...
#  intensity_user       | 0.027575641516660282
#  features             | [754230.0,11520.0...
# only showing top 20 rows

# %%
from pyspark.ml.feature import MinMaxScaler
scaler = MinMaxScaler(inputCol='features', outputCol='features_minmax')
scaler_model = scaler.fit(df_train)
items1 = scaler_model.transform(df_train)

# %%
items1.show(vertical=True)
# Out:
# -RECORD 0------------------------------------
#  user_id              | 754230
#  item_id              | 540
#  purchase             | 0
#  title                | мой парень  псих
#  year                 | 2012.0
#  genres               | Комедии,Драмы,Мел...
#  genres_word          | [Комедии, Драмы, ...
#  title_words          | [мой, парень, , п...
#  title_words_filtered | [парень, , псих]
#  word_vector          | (200,[44,164,172]...
#  genre_vector         | (83,[0,1,2,7],[1....
#  item_mean_encoding   | 7.23589001447178E-4
#  intensity_user       | 0.027575641516660282
#  features             | [754230.0,540.0,7...
#  features_minmax      | [0.80078655367760...
# -RECORD 1------------------------------------
#  user_id              | 754230
#  item_id              | 1522
#  purchase             | 0
#  title                | патруль времени
#  year                 | 1994.0
#  genres               | Триллеры,Фантасти...
#  genres_word          | [Триллеры, Фантас...
#  title_words          | [патруль, времени]
#  title_words_filtered | [патруль, времени]
#  word_vector          | (200,[68,128],[1....
#  genre_vector         | (83,[0,3,5,7,12],...
#  item_mean_encoding   | 7.507507507507507E-4
#  intensity_user       | 0.027575641516660282
#  features             | [754230.0,1522.0,...
#  features_minmax      | [0.80078655367760...
# -RECORD 2------------------------------------
#  user_id              | 754230
#  item_id              | 2999
#  purchase             | 0
#  title                | блондинка в эфире
#  year                 | 2014.0
#  genres               | Приключения,Комед...
#  genres_word          | [Приключения, Ком...
#  title_words          | [блондинка, в, эф...
#  title_words_filtered | [блондинка, эфире]
#  word_vector          | (200,[19,70],[1.0...
#  genre_vector         | (83,[0,2,8],[1.0,...
#  item_mean_encoding   | 0.003644314868804...
#  intensity_user       | 0.027575641516660282
#  features             | [754230.0,2999.0,...
#  features_minmax      | [0.80078655367760...
# -RECORD 3------------------------------------
#  user_id              | 754230
#  item_id              | 10914
#  purchase             | 0
#  title                | фазенда
#  year                 | 2012.0
#  genres               | Познавательные
#  genres_word          | [Познавательные]
#  title_words          | [фазенда]
#  title_words_filtered | [фазенда]
#  word_vector          | (200,[140],[1.0])
#  genre_vector         | (83,[33],[1.0])
#  item_mean_encoding   | 7.320644216691069E-4
#  intensity_user       | 0.027575641516660282
#  features             | [754230.0,10914.0...
#  features_minmax      | [0.80078655367760...
# -RECORD 4------------------------------------
#  user_id              | 754230
#  item_id              | 68609
#  purchase             | 0
#  title                | полной грудью
#  year                 | 2013.0
#  genres               | Драмы,Мелодрамы,З...
#  genres_word          | [Драмы, Мелодрамы...
#  title_words          | [полной, грудью]
#  title_words_filtered | [полной, грудью]
#  word_vector          | (200,[79,186],[1....
#  genre_vector         | (83,[0,1,7],[1.0,...
#  item_mean_encoding   | 0.002188183807439825
#  intensity_user       | 0.027575641516660282
#  features             | [754230.0,68609.0...
#  features_minmax      | [0.80078655367760...
# -RECORD 5------------------------------------
#  user_id              | 754230
#  item_id              | 76701
#  purchase             | 0
#  title                | как утёнокмузыкан...
#  year                 | 1978.0
#  genres               | Советские,Для детей
#  genres_word          | [Советские, Для д...
#  title_words          | [как, утёнокмузык...
#  title_words_filtered | [утёнокмузыкант, ...
#  word_vector          | (200,[14,36,77],[...
#  genre_vector         | (83,[9,21],[1.0,1...
#  item_mean_encoding   | 7.23589001447178E-4
#  intensity_user       | 0.027575641516660282
#  features             | [754230.0,76701.0...
#  features_minmax      | [0.80078655367760...
# -RECORD 6------------------------------------
#  user_id              | 754230
#  item_id              | 78272
#  purchase             | 0
#  title                | люблю твою жену
#  year                 | 2013.0
#  genres               | Комедии,Мелодрамы...
#  genres_word          | [Комедии, Мелодра...
#  title_words          | [люблю, твою, жену]
#  title_words_filtered | [люблю, твою, жену]
#  word_vector          | (200,[21,34,132],...
#  genre_vector         | (83,[0,2,7],[1.0,...
#  item_mean_encoding   | 0.002169197396963...
#  intensity_user       | 0.027575641516660282
#  features             | [754230.0,78272.0...
#  features_minmax      | [0.80078655367760...
# -RECORD 7------------------------------------
#  user_id              | 754230
#  item_id              | 90493
#  purchase             | 0
#  title                | навигатор игровог...
#  year                 | 2016.0
#  genres               | Развлекательные,В...
#  genres_word          | [Развлекательные,...
#  title_words          | [навигатор, игров...
#  title_words_filtered | [навигатор, игров...
#  word_vector          | (200,[4,57,152,18...
#  genre_vector         | (83,[4,33,40,45],...
#  item_mean_encoding   | 0.0
#  intensity_user       | 0.027575641516660282
#  features             | [754230.0,90493.0...
#  features_minmax      | [0.80078655367760...
# -RECORD 8------------------------------------
#  user_id              | 754230
#  item_id              | 92858
#  purchase             | 0
#  title                | сказка о царе сал...
#  year                 | 1966.0
#  genres               | Приключения,Совет...
#  genres_word          | [Приключения, Сов...
#  title_words          | [сказка, о, царе,...
#  title_words_filtered | [сказка, царе, са...
#  word_vector          | (200,[2,102,149],...
#  genre_vector         | (83,[8,9,24,34,46...
#  item_mean_encoding   | 0.001436781609195...
#  intensity_user       | 0.027575641516660282
#  features             | [754230.0,92858.0...
#  features_minmax      | [0.80078655367760...
# -RECORD 9------------------------------------
#  user_id              | 754230
#  item_id              | 94621
#  purchase             | 0
#  title                | антихрист
#  year                 | 2008.0
#  genres               | Ужасы,Драмы,Заруб...
#  genres_word          | [Ужасы, Драмы, За...
#  title_words          | [антихрист]
#  title_words_filtered | [антихрист]
#  word_vector          | (200,[177],[1.0])
#  genre_vector         | (83,[0,1,10],[1.0...
#  item_mean_encoding   | 7.541478129713424E-4
#  intensity_user       | 0.027575641516660282
#  features             | [754230.0,94621.0...
#  features_minmax      | [0.80078655367760...
# -RECORD 10-----------------------------------
#  user_id              | 754230
#  item_id              | 100453
#  purchase             | 0
#  title                | играй до смерти
#  year                 | 2011.0
#  genres               | Ужасы,Триллеры,За...
#  genres_word          | [Ужасы, Триллеры,...
#  title_words          | [играй, до, смерти]
#  title_words_filtered | [играй, смерти]
#  word_vector          | (200,[138,155],[1...
#  genre_vector         | (83,[0,3,10],[1.0...
#  item_mean_encoding   | 0.001441961067051...
#  intensity_user       | 0.027575641516660282
#  features             | [754230.0,100453....
#  features_minmax      | [0.80078655367760...
# -RECORD 11-----------------------------------
#  user_id              | 754230
#  item_id              | 7098
#  purchase             | 0
#  title                | цветиксемицветик
#  year                 | 1948.0
#  genres               | Мультфильмы,Детск...
#  genres_word          | [Мультфильмы, Дет...
#  title_words          | [цветиксемицветик]
#  title_words_filtered | [цветиксемицветик]
#  word_vector          | (200,[54],[1.0])
#  genre_vector         | (83,[6,14,19,23],...
#  item_mean_encoding   | 0.0
#  intensity_user       | 0.027575641516660282
#  features             | [754230.0,7098.0,...
#  features_minmax      | [0.80078655367760...
# -RECORD 12-----------------------------------
#  user_id              | 754230
#  item_id              | 7644
#  purchase             | 0
#  title                | самый маленький гном
#  year                 | 1977.0
#  genres               | Мультфильмы,Детск...
#  genres_word          | [Мультфильмы, Дет...
#  title_words          | [самый, маленький...
#  title_words_filtered | [самый, маленький...
#  word_vector          | (200,[10,129,168]...
#  genre_vector         | (83,[6,14,19,23],...
#  item_mean_encoding   | 0.001472754050073...
#  intensity_user       | 0.027575641516660282
#  features             | [754230.0,7644.0,...
#  features_minmax      | [0.80078655367760...
# -RECORD 13-----------------------------------
#  user_id              | 754230
#  item_id              | 65879
#  purchase             | 0
#  title                | книга илая (сурдо...
#  year                 | 2009.0
#  genres               | Триллеры,Боевики,...
#  genres_word          | [Триллеры, Боевик...
#  title_words          | [книга, илая, (су...
#  title_words_filtered | [книга, илая, (су...
#  word_vector          | (200,[44,141,187]...
#  genre_vector         | (83,[0,3,5],[1.0,...
#  item_mean_encoding   | 0.005124450951683748
#  intensity_user       | 0.027575641516660282
#  features             | [754230.0,65879.0...
#  features_minmax      | [0.80078655367760...
# -RECORD 14-----------------------------------
#  user_id              | 754230
#  item_id              | 66594
#  purchase             | 0
#  title                | экипаж
#  year                 | 2016.0
#  genres               | Приключения,Трилл...
#  genres_word          | [Приключения, Три...
#  title_words          | [экипаж]
#  title_words_filtered | [экипаж]
#  word_vector          | (200,[105],[1.0])
#  genre_vector         | (83,[1,3,8],[1.0,...
#  item_mean_encoding   | 0.01581325301204819
#  intensity_user       | 0.027575641516660282
#  features             | [754230.0,66594.0...
#  features_minmax      | [0.80078655367760...
# -RECORD 15-----------------------------------
#  user_id              | 754230
#  item_id              | 74318
#  purchase             | 0
#  title                | падение олимпа
#  year                 | 2013.0
#  genres               | Триллеры,Боевики,...
#  genres_word          | [Триллеры, Боевик...
#  title_words          | [падение, олимпа]
#  title_words_filtered | [падение, олимпа]
#  word_vector          | (200,[71,93],[1.0...
#  genre_vector         | (83,[0,3,5],[1.0,...
#  item_mean_encoding   | 0.003717472118959...
#  intensity_user       | 0.027575641516660282
#  features             | [754230.0,74318.0...
#  features_minmax      | [0.80078655367760...
# -RECORD 16-----------------------------------
#  user_id              | 754230
#  item_id              | 81832
#  purchase             | 0
#  title                | неупокоенная
#  year                 | 2014.0
#  genres               | Мистические,Ужасы...
#  genres_word          | [Мистические, Ужа...
#  title_words          | [неупокоенная]
#  title_words_filtered | [неупокоенная]
#  word_vector          | (200,[173],[1.0])
#  genre_vector         | (83,[0,3,10,30],[...
#  item_mean_encoding   | 7.429420505200594E-4
#  intensity_user       | 0.027575641516660282
#  features             | [754230.0,81832.0...
#  features_minmax      | [0.80078655367760...
# -RECORD 17-----------------------------------
#  user_id              | 754230
#  item_id              | 91200
#  purchase             | 0
#  title                | не входить мы не ...
#  year                 | 2012.0
#  genres               | Комедии,Драмы,Мел...
#  genres_word          | [Комедии, Драмы, ...
#  title_words          | [не, входить, мы,...
#  title_words_filtered | [входить, одеты]
#  word_vector          | (200,[42,109],[1....
#  genre_vector         | (83,[0,1,2,7],[1....
#  item_mean_encoding   | 7.358351729212656E-4
#  intensity_user       | 0.027575641516660282
#  features             | [754230.0,91200.0...
#  features_minmax      | [0.80078655367760...
# -RECORD 18-----------------------------------
#  user_id              | 754230
#  item_id              | 94722
#  purchase             | 0
#  title                | приключения мышонка
#  year                 | 2013.0
#  genres               | Полнометражные,Дл...
#  genres_word          | [Полнометражные, ...
#  title_words          | [приключения, мыш...
#  title_words_filtered | [приключения, мыш...
#  word_vector          | (200,[76,143],[1....
#  genre_vector         | (83,[0,9,18],[1.0...
#  item_mean_encoding   | 0.0
#  intensity_user       | 0.027575641516660282
#  features             | [754230.0,94722.0...
#  features_minmax      | [0.80078655367760...
# -RECORD 19-----------------------------------
#  user_id              | 754230
#  item_id              | 97828
#  purchase             | 0
#  title                | я знаменитость
#  year                 | 2008.0
#  genres               | Эротика,Зарубежные
#  genres_word          | [Эротика, Зарубеж...
#  title_words          | [я, знаменитость]
#  title_words_filtered | [знаменитость]
#  word_vector          | (200,[123],[1.0])
#  genre_vector         | (83,[0,20],[1.0,1...
#  item_mean_encoding   | 7.251631617113851E-4
#  intensity_user       | 0.027575641516660282
#  features             | [754230.0,97828.0...
#  features_minmax      | [0.80078655367760...
# only showing top 20 rows

# %%
from pyspark.ml.feature import MinMaxScaler
scaler = MinMaxScaler(inputCol='features', outputCol='features_minmax')
scaler_model = scaler.fit(test)
test = scaler_model.transform(test)

# %% [markdown]
# # разбиваем на train и val

# %%
train = df_train.sampleBy("purchase", fractions={0: 0.8, 1: 0.8}, seed=5757)

# %%
val = df_train.join(train, (df_train.item_id == train.item_id) & (df_train.user_id == train.user_id), how="leftanti")

# %%
from pyspark.ml.classification import LogisticRegression

# %%
lr = LogisticRegression(featuresCol='features', labelCol="purchase", maxIter=15)

# %%
lr_model = lr.fit(train)

# %%
predictions = lr_model.transform(val)

# %%
df_train.groupby("purchase").count().collect()

# %% [markdown]
# # Обучение

# %%
from pyspark.ml.classification import LogisticRegression

# %%
lr = LogisticRegression(featuresCol='features_minmax', labelCol="purchase", maxIter=15)

# %%
lr_model_final = lr.fit(items1)

# %%
predictions = lr_model_final.transform(test)

# %%
predictions.show(vertical=True)
# Out:
# -RECORD 0------------------------------------
#  user_id              | 754230
#  item_id              | 93486
#  title                | виноградник
#  year                 | 2014.0
#  genres               | Триллеры,Фантастика
#  genres_word          | [Триллеры, Фантас...
#  title_words          | [виноградник]
#  title_words_filtered | [виноградник]
#  word_vector          | (200,[33],[1.0])
#  genre_vector         | (83,[3,12],[1.0,1...
#  item_mean_encoding   | 0.002141327623126...
#  intensity_user       | 0.027575641516660282
#  features             | [754230.0,93486.0...
#  features_minmax      | [0.80078655367760...
#  rawPrediction        | [5.68888967833494...
#  probability          | [0.99662806095286...
#  prediction           | 0.0
# -RECORD 1------------------------------------
#  user_id              | 754230
#  item_id              | 94819
#  title                | невидимый мир
#  year                 | 2011.0
#  genres               | Драмы,Зарубежные
#  genres_word          | [Драмы, Зарубежные]
#  title_words          | [невидимый, мир]
#  title_words_filtered | [невидимый, мир]
#  word_vector          | (200,[26,100],[1....
#  genre_vector         | (83,[0,1],[1.0,1.0])
#  item_mean_encoding   | 7.163323782234957E-4
#  intensity_user       | 0.027575641516660282
#  features             | [754230.0,94819.0...
#  features_minmax      | [0.80078655367760...
#  rawPrediction        | [5.81168491467520...
#  probability          | [0.99701654373574...
#  prediction           | 0.0
# -RECORD 2------------------------------------
#  user_id              | 754230
#  item_id              | 73041
#  title                | коко до шанель
#  year                 | 2009.0
#  genres               | Драмы,Исторически...
#  genres_word          | [Драмы, Историчес...
#  title_words          | [коко, до, шанель]
#  title_words_filtered | [коко, шанель]
#  word_vector          | (200,[63,108],[1....
#  genre_vector         | (83,[0,1,25],[1.0...
#  item_mean_encoding   | 7.352941176470588E-4
#  intensity_user       | 0.027575641516660282
#  features             | [754230.0,73041.0...
#  features_minmax      | [0.80078655367760...
#  rawPrediction        | [5.74976825348703...
#  probability          | [0.99682658414767...
#  prediction           | 0.0
# -RECORD 3------------------------------------
#  user_id              | 754230
#  item_id              | 74440
#  title                | области тьмы
#  year                 | 2011.0
#  genres               | Детективы,Фантаст...
#  genres_word          | [Детективы, Фанта...
#  title_words          | [области, тьмы]
#  title_words_filtered | [области, тьмы]
#  word_vector          | (200,[79,152],[1....
#  genre_vector         | (83,[0,11,12],[1....
#  item_mean_encoding   | 0.00363901018922853
#  intensity_user       | 0.027575641516660282
#  features             | [754230.0,74440.0...
#  features_minmax      | [0.80078655367760...
#  rawPrediction        | [5.51094865938592...
#  probability          | [0.99597400334327...
#  prediction           | 0.0
# -RECORD 4------------------------------------
#  user_id              | 754230
#  item_id              | 74452
#  title                | я плюю на ваши мо...
#  year                 | 2013.0
#  genres               | Ужасы,Триллеры,Кр...
#  genres_word          | [Ужасы, Триллеры,...
#  title_words          | [я, плюю, на, ваш...
#  title_words_filtered | [плюю, ваши, моги...
#  word_vector          | (200,[93,123,175]...
#  genre_vector         | (83,[0,3,10,13],[...
#  item_mean_encoding   | 0.001488095238095238
#  intensity_user       | 0.027575641516660282
#  features             | [754230.0,74452.0...
#  features_minmax      | [0.80078655367760...
#  rawPrediction        | [5.69075735192277...
#  probability          | [0.99663433158088...
#  prediction           | 0.0
# -RECORD 5------------------------------------
#  user_id              | 754230
#  item_id              | 93131
#  title                | навигатор игровог...
#  year                 | 2015.0
#  genres               | Развлекательные,В...
#  genres_word          | [Развлекательные,...
#  title_words          | [навигатор, игров...
#  title_words_filtered | [навигатор, игров...
#  word_vector          | (200,[57,152,181,...
#  genre_vector         | (83,[4,33,40,45],...
#  item_mean_encoding   | 7.293946024799417E-4
#  intensity_user       | 0.027575641516660282
#  features             | [754230.0,93131.0...
#  features_minmax      | [0.80078655367760...
#  rawPrediction        | [5.80591687787874...
#  probability          | [0.99699933711117...
#  prediction           | 0.0
# -RECORD 6------------------------------------
#  user_id              | 754230
#  item_id              | 93633
#  title                | три богатыря на д...
#  year                 | 2012.0
#  genres               | Приключения,Комед...
#  genres_word          | [Приключения, Ком...
#  title_words          | [три, богатыря, н...
#  title_words_filtered | [богатыря, дальни...
#  word_vector          | (200,[21,106,169,...
#  genre_vector         | (83,[2,8,12],[1.0...
#  item_mean_encoding   | 0.002212389380530...
#  intensity_user       | 0.027575641516660282
#  features             | [754230.0,93633.0...
#  features_minmax      | [0.80078655367760...
#  rawPrediction        | [5.68335750696882...
#  probability          | [0.99660941853764...
#  prediction           | 0.0
# -RECORD 7------------------------------------
#  user_id              | 754230
#  item_id              | 95151
#  title                | невеста
#  year                 | 2017.0
#  genres               | Мистические,Ужасы...
#  genres_word          | [Мистические, Ужа...
#  title_words          | [невеста]
#  title_words_filtered | [невеста]
#  word_vector          | (200,[196],[1.0])
#  genre_vector         | (83,[3,4,10,30],[...
#  item_mean_encoding   | 0.001456664238892...
#  intensity_user       | 0.027575641516660282
#  features             | [754230.0,95151.0...
#  features_minmax      | [0.80078655367760...
#  rawPrediction        | [5.75072704030030...
#  probability          | [0.99682961567711...
#  prediction           | 0.0
# -RECORD 8------------------------------------
#  user_id              | 754230
#  item_id              | 11025
#  title                | рэтчет и кланк га...
#  year                 | 2016.0
#  genres               | Приключения,Комед...
#  genres_word          | [Приключения, Ком...
#  title_words          | [рэтчет, и, кланк...
#  title_words_filtered | [рэтчет, кланк, г...
#  word_vector          | (200,[76,102,115,...
#  genre_vector         | (83,[0,2,5,8,12],...
#  item_mean_encoding   | 0.0
#  intensity_user       | 0.027575641516660282
#  features             | [754230.0,11025.0...
#  features_minmax      | [0.80078655367760...
#  rawPrediction        | [5.63942123718118...
#  probability          | [0.99645766745795...
#  prediction           | 0.0
# -RECORD 9------------------------------------
#  user_id              | 754230
#  item_id              | 72912
#  title                | хорошо сидим
#  year                 | 1986.0
#  genres               | Комедии,Наши
#  genres_word          | [Комедии, Наши]
#  title_words          | [хорошо, сидим]
#  title_words_filtered | [сидим]
#  word_vector          | (200,[196],[1.0])
#  genre_vector         | (83,[2,6],[1.0,1.0])
#  item_mean_encoding   | 0.0
#  intensity_user       | 0.027575641516660282
#  features             | [754230.0,72912.0...
#  features_minmax      | [0.80078655367760...
#  rawPrediction        | [5.81086744169616...
#  probability          | [0.99701411112897...
#  prediction           | 0.0
# -RECORD 10-----------------------------------
#  user_id              | 754230
#  item_id              | 86406
#  title                | стритрейсеры
#  year                 | 2008.0
#  genres               | Русские,Боевики
#  genres_word          | [Русские, Боевики]
#  title_words          | [стритрейсеры]
#  title_words_filtered | [стритрейсеры]
#  word_vector          | (200,[182],[1.0])
#  genre_vector         | (83,[4,5],[1.0,1.0])
#  item_mean_encoding   | 0.0
#  intensity_user       | 0.027575641516660282
#  features             | [754230.0,86406.0...
#  features_minmax      | [0.80078655367760...
#  rawPrediction        | [5.84825001127823...
#  probability          | [0.99712335559468...
#  prediction           | 0.0
# -RECORD 11-----------------------------------
#  user_id              | 754230
#  item_id              | 88999
#  title                | пираньи 3dd
#  year                 | 2012.0
#  genres               | Ужасы,Комедии,Три...
#  genres_word          | [Ужасы, Комедии, ...
#  title_words          | [пираньи, 3dd]
#  title_words_filtered | [пираньи, 3dd]
#  word_vector          | (200,[112,143],[1...
#  genre_vector         | (83,[0,2,3,10],[1...
#  item_mean_encoding   | 0.004411764705882353
#  intensity_user       | 0.027575641516660282
#  features             | [754230.0,88999.0...
#  features_minmax      | [0.80078655367760...
#  rawPrediction        | [5.48669407678182...
#  probability          | [0.99587556829599...
#  prediction           | 0.0
# -RECORD 12-----------------------------------
#  user_id              | 754230
#  item_id              | 93487
#  title                | инфекция фаза 2
#  year                 | 2015.0
#  genres               | Ужасы,Триллеры,Драмы
#  genres_word          | [Ужасы, Триллеры,...
#  title_words          | [инфекция, фаза, 2]
#  title_words_filtered | [инфекция, фаза, 2]
#  word_vector          | (200,[25,144,189]...
#  genre_vector         | (83,[1,3,10],[1.0...
#  item_mean_encoding   | 0.003023431594860...
#  intensity_user       | 0.027575641516660282
#  features             | [754230.0,93487.0...
#  features_minmax      | [0.80078655367760...
#  rawPrediction        | [5.61516538782744...
#  probability          | [0.99637101026124...
#  prediction           | 0.0
# -RECORD 13-----------------------------------
#  user_id              | 754230
#  item_id              | 9071
#  title                | любовь в большом ...
#  year                 | 2009.0
#  genres               | Комедии,Фантастик...
#  genres_word          | [Комедии, Фантаст...
#  title_words          | [любовь, в, больш...
#  title_words_filtered | [любовь, большом,...
#  word_vector          | (200,[15,93,100],...
#  genre_vector         | (83,[2,6,7,12],[1...
#  item_mean_encoding   | 0.0
#  intensity_user       | 0.027575641516660282
#  features             | [754230.0,9071.0,...
#  features_minmax      | [0.80078655367760...
#  rawPrediction        | [5.63400805050834...
#  probability          | [0.99643850863497...
#  prediction           | 0.0
# -RECORD 14-----------------------------------
#  user_id              | 754230
#  item_id              | 72387
#  title                | метод
#  year                 | 2015.0
#  genres               | Детективы,Драмы,Т...
#  genres_word          | [Детективы, Драмы...
#  title_words          | [метод]
#  title_words_filtered | [метод]
#  word_vector          | (200,[52],[1.0])
#  genre_vector         | (83,[1,3,4,11],[1...
#  item_mean_encoding   | 0.0
#  intensity_user       | 0.027575641516660282
#  features             | [754230.0,72387.0...
#  features_minmax      | [0.80078655367760...
#  rawPrediction        | [5.80941302869553...
#  probability          | [0.99700977824892...
#  prediction           | 0.0
# -RECORD 15-----------------------------------
#  user_id              | 754230
#  item_id              | 78269
#  title                | секс  за деньги л...
#  year                 | 2011.0
#  genres               | Комедии,Зарубежные
#  genres_word          | [Комедии, Зарубеж...
#  title_words          | [секс, , за, день...
#  title_words_filtered | [секс, , деньги, ...
#  word_vector          | (200,[68,93,100,1...
#  genre_vector         | (83,[0,2],[1.0,1.0])
#  item_mean_encoding   | 0.0
#  intensity_user       | 0.027575641516660282
#  features             | [754230.0,78269.0...
#  features_minmax      | [0.80078655367760...
#  rawPrediction        | [5.82570799492361...
#  probability          | [0.99705796677765...
#  prediction           | 0.0
# -RECORD 16-----------------------------------
#  user_id              | 754230
#  item_id              | 93477
#  title                | застава
#  year                 | 2007.0
#  genres               | Военные,Драмы
#  genres_word          | [Военные, Драмы]
#  title_words          | [застава]
#  title_words_filtered | [застава]
#  word_vector          | (200,[186],[1.0])
#  genre_vector         | (83,[1,16],[1.0,1...
#  item_mean_encoding   | 7.25689404934688E-4
#  intensity_user       | 0.027575641516660282
#  features             | [754230.0,93477.0...
#  features_minmax      | [0.80078655367760...
#  rawPrediction        | [5.80718508912070...
#  probability          | [0.99700312877624...
#  prediction           | 0.0
# -RECORD 17-----------------------------------
#  user_id              | 754230
#  item_id              | 94726
#  title                | я прихожу с дождем
#  year                 | 2009.0
#  genres               | Триллеры,Драмы,За...
#  genres_word          | [Триллеры, Драмы,...
#  title_words          | [я, прихожу, с, д...
#  title_words_filtered | [прихожу, дождем]
#  word_vector          | (200,[150,151],[1...
#  genre_vector         | (83,[0,1,3],[1.0,...
#  item_mean_encoding   | 0.001490312965722...
#  intensity_user       | 0.027575641516660282
#  features             | [754230.0,94726.0...
#  features_minmax      | [0.80078655367760...
#  rawPrediction        | [5.74673726682789...
#  probability          | [0.99681698163749...
#  prediction           | 0.0
# -RECORD 18-----------------------------------
#  user_id              | 754230
#  item_id              | 10788
#  title                | карибские острова...
#  year                 | 2012.0
#  genres               | Документальные,За...
#  genres_word          | [Документальные, ...
#  title_words          | [карибские, остро...
#  title_words_filtered | [карибские, остро...
#  word_vector          | (200,[32,39,144,1...
#  genre_vector         | (83,[0,27],[1.0,1...
#  item_mean_encoding   | 0.004347826086956522
#  intensity_user       | 0.027575641516660282
#  features             | [754230.0,10788.0...
#  features_minmax      | [0.80078655367760...
#  rawPrediction        | [5.27536937257814...
#  probability          | [0.99490997428616...
#  prediction           | 0.0
# -RECORD 19-----------------------------------
#  user_id              | 754230
#  item_id              | 11520
#  title                | спасение
#  year                 | 2015.0
#  genres               | Триллеры,Боевики,...
#  genres_word          | [Триллеры, Боевик...
#  title_words          | [спасение]
#  title_words_filtered | [спасение]
#  word_vector          | (200,[2],[1.0])
#  genre_vector         | (83,[0,3,5],[1.0,...
#  item_mean_encoding   | 0.001457725947521...
#  intensity_user       | 0.027575641516660282
#  features             | [754230.0,11520.0...
#  features_minmax      | [0.80078655367760...
#  rawPrediction        | [5.51895446618152...
#  probability          | [0.99600597780049...
#  prediction           | 0.0
# only showing top 20 rows

# %%
prediction = predictions.select('user_id', 'item_id', 'prediction')

# %%
prediction.groupby("prediction").count().collect()
# Out:
# [Row(prediction=0.0, count=2156790), Row(prediction=1.0, count=50)]

# %%
def proba1(vector):
    from pyspark.ml.linalg import Vectors
   # res = float(vector.dot(Vectors.dense([0.0, 1.0])))
    res = float(vector[1])
    return res
proba1 = udf(proba1, FloatType())

# %%
predictions1 = predictions.select('*', proba1('probability').alias('purchase'))

# %%
predictions1.show(vertical=True)
# Out:
# -RECORD 0------------------------------------
#  user_id              | 754230
#  item_id              | 73041
#  title                | коко до шанель
#  year                 | 2009.0
#  genres               | Драмы,Исторически...
#  genres_word          | [Драмы, Историчес...
#  title_words          | [коко, до, шанель]
#  title_words_filtered | [коко, шанель]
#  word_vector          | (200,[63,108],[1....
#  genre_vector         | (83,[0,1,25],[1.0...
#  item_mean_encoding   | 7.352941176470588E-4
#  intensity_user       | 0.027575641516660282
#  features             | [754230.0,73041.0...
#  features_minmax      | [0.80078655367760...
#  rawPrediction        | [5.74976825348703...
#  probability          | [0.99682658414767...
#  prediction           | 0.0
#  purchase             | 0.0031734158
# -RECORD 1------------------------------------
#  user_id              | 754230
#  item_id              | 74440
#  title                | области тьмы
#  year                 | 2011.0
#  genres               | Детективы,Фантаст...
#  genres_word          | [Детективы, Фанта...
#  title_words          | [области, тьмы]
#  title_words_filtered | [области, тьмы]
#  word_vector          | (200,[79,152],[1....
#  genre_vector         | (83,[0,11,12],[1....
#  item_mean_encoding   | 0.00363901018922853
#  intensity_user       | 0.027575641516660282
#  features             | [754230.0,74440.0...
#  features_minmax      | [0.80078655367760...
#  rawPrediction        | [5.51094865938592...
#  probability          | [0.99597400334327...
#  prediction           | 0.0
#  purchase             | 0.0040259967
# -RECORD 2------------------------------------
#  user_id              | 754230
#  item_id              | 74452
#  title                | я плюю на ваши мо...
#  year                 | 2013.0
#  genres               | Ужасы,Триллеры,Кр...
#  genres_word          | [Ужасы, Триллеры,...
#  title_words          | [я, плюю, на, ваш...
#  title_words_filtered | [плюю, ваши, моги...
#  word_vector          | (200,[93,123,175]...
#  genre_vector         | (83,[0,3,10,13],[...
#  item_mean_encoding   | 0.001488095238095238
#  intensity_user       | 0.027575641516660282
#  features             | [754230.0,74452.0...
#  features_minmax      | [0.80078655367760...
#  rawPrediction        | [5.69075735192277...
#  probability          | [0.99663433158088...
#  prediction           | 0.0
#  purchase             | 0.0033656685
# -RECORD 3------------------------------------
#  user_id              | 754230
#  item_id              | 93131
#  title                | навигатор игровог...
#  year                 | 2015.0
#  genres               | Развлекательные,В...
#  genres_word          | [Развлекательные,...
#  title_words          | [навигатор, игров...
#  title_words_filtered | [навигатор, игров...
#  word_vector          | (200,[57,152,181,...
#  genre_vector         | (83,[4,33,40,45],...
#  item_mean_encoding   | 7.293946024799417E-4
#  intensity_user       | 0.027575641516660282
#  features             | [754230.0,93131.0...
#  features_minmax      | [0.80078655367760...
#  rawPrediction        | [5.80591687787874...
#  probability          | [0.99699933711117...
#  prediction           | 0.0
#  purchase             | 0.003000663
# -RECORD 4------------------------------------
#  user_id              | 754230
#  item_id              | 93633
#  title                | три богатыря на д...
#  year                 | 2012.0
#  genres               | Приключения,Комед...
#  genres_word          | [Приключения, Ком...
#  title_words          | [три, богатыря, н...
#  title_words_filtered | [богатыря, дальни...
#  word_vector          | (200,[21,106,169,...
#  genre_vector         | (83,[2,8,12],[1.0...
#  item_mean_encoding   | 0.002212389380530...
#  intensity_user       | 0.027575641516660282
#  features             | [754230.0,93633.0...
#  features_minmax      | [0.80078655367760...
#  rawPrediction        | [5.68335750696882...
#  probability          | [0.99660941853764...
#  prediction           | 0.0
#  purchase             | 0.0033905813
# -RECORD 5------------------------------------
#  user_id              | 754230
#  item_id              | 95151
#  title                | невеста
#  year                 | 2017.0
#  genres               | Мистические,Ужасы...
#  genres_word          | [Мистические, Ужа...
#  title_words          | [невеста]
#  title_words_filtered | [невеста]
#  word_vector          | (200,[196],[1.0])
#  genre_vector         | (83,[3,4,10,30],[...
#  item_mean_encoding   | 0.001456664238892...
#  intensity_user       | 0.027575641516660282
#  features             | [754230.0,95151.0...
#  features_minmax      | [0.80078655367760...
#  rawPrediction        | [5.75072704030030...
#  probability          | [0.99682961567711...
#  prediction           | 0.0
#  purchase             | 0.0031703843
# -RECORD 6------------------------------------
#  user_id              | 754230
#  item_id              | 11025
#  title                | рэтчет и кланк га...
#  year                 | 2016.0
#  genres               | Приключения,Комед...
#  genres_word          | [Приключения, Ком...
#  title_words          | [рэтчет, и, кланк...
#  title_words_filtered | [рэтчет, кланк, г...
#  word_vector          | (200,[76,102,115,...
#  genre_vector         | (83,[0,2,5,8,12],...
#  item_mean_encoding   | 0.0
#  intensity_user       | 0.027575641516660282
#  features             | [754230.0,11025.0...
#  features_minmax      | [0.80078655367760...
#  rawPrediction        | [5.63942123718118...
#  probability          | [0.99645766745795...
#  prediction           | 0.0
#  purchase             | 0.0035423324
# -RECORD 7------------------------------------
#  user_id              | 754230
#  item_id              | 72912
#  title                | хорошо сидим
#  year                 | 1986.0
#  genres               | Комедии,Наши
#  genres_word          | [Комедии, Наши]
#  title_words          | [хорошо, сидим]
#  title_words_filtered | [сидим]
#  word_vector          | (200,[196],[1.0])
#  genre_vector         | (83,[2,6],[1.0,1.0])
#  item_mean_encoding   | 0.0
#  intensity_user       | 0.027575641516660282
#  features             | [754230.0,72912.0...
#  features_minmax      | [0.80078655367760...
#  rawPrediction        | [5.81086744169616...
#  probability          | [0.99701411112897...
#  prediction           | 0.0
#  purchase             | 0.0029858889
# -RECORD 8------------------------------------
#  user_id              | 754230
#  item_id              | 86406
#  title                | стритрейсеры
#  year                 | 2008.0
#  genres               | Русские,Боевики
#  genres_word          | [Русские, Боевики]
#  title_words          | [стритрейсеры]
#  title_words_filtered | [стритрейсеры]
#  word_vector          | (200,[182],[1.0])
#  genre_vector         | (83,[4,5],[1.0,1.0])
#  item_mean_encoding   | 0.0
#  intensity_user       | 0.027575641516660282
#  features             | [754230.0,86406.0...
#  features_minmax      | [0.80078655367760...
#  rawPrediction        | [5.84825001127823...
#  probability          | [0.99712335559468...
#  prediction           | 0.0
#  purchase             | 0.0028766445
# -RECORD 9------------------------------------
#  user_id              | 754230
#  item_id              | 88999
#  title                | пираньи 3dd
#  year                 | 2012.0
#  genres               | Ужасы,Комедии,Три...
#  genres_word          | [Ужасы, Комедии, ...
#  title_words          | [пираньи, 3dd]
#  title_words_filtered | [пираньи, 3dd]
#  word_vector          | (200,[112,143],[1...
#  genre_vector         | (83,[0,2,3,10],[1...
#  item_mean_encoding   | 0.004411764705882353
#  intensity_user       | 0.027575641516660282
#  features             | [754230.0,88999.0...
#  features_minmax      | [0.80078655367760...
#  rawPrediction        | [5.48669407678182...
#  probability          | [0.99587556829599...
#  prediction           | 0.0
#  purchase             | 0.004124432
# -RECORD 10-----------------------------------
#  user_id              | 754230
#  item_id              | 93487
#  title                | инфекция фаза 2
#  year                 | 2015.0
#  genres               | Ужасы,Триллеры,Драмы
#  genres_word          | [Ужасы, Триллеры,...
#  title_words          | [инфекция, фаза, 2]
#  title_words_filtered | [инфекция, фаза, 2]
#  word_vector          | (200,[25,144,189]...
#  genre_vector         | (83,[1,3,10],[1.0...
#  item_mean_encoding   | 0.003023431594860...
#  intensity_user       | 0.027575641516660282
#  features             | [754230.0,93487.0...
#  features_minmax      | [0.80078655367760...
#  rawPrediction        | [5.61516538782744...
#  probability          | [0.99637101026124...
#  prediction           | 0.0
#  purchase             | 0.0036289897
# -RECORD 11-----------------------------------
#  user_id              | 754230
#  item_id              | 10788
#  title                | карибские острова...
#  year                 | 2012.0
#  genres               | Документальные,За...
#  genres_word          | [Документальные, ...
#  title_words          | [карибские, остро...
#  title_words_filtered | [карибские, остро...
#  word_vector          | (200,[32,39,144,1...
#  genre_vector         | (83,[0,27],[1.0,1...
#  item_mean_encoding   | 0.004347826086956522
#  intensity_user       | 0.027575641516660282
#  features             | [754230.0,10788.0...
#  features_minmax      | [0.80078655367760...
#  rawPrediction        | [5.27536937257814...
#  probability          | [0.99490997428616...
#  prediction           | 0.0
#  purchase             | 0.0050900257
# -RECORD 12-----------------------------------
#  user_id              | 754230
#  item_id              | 11520
#  title                | спасение
#  year                 | 2015.0
#  genres               | Триллеры,Боевики,...
#  genres_word          | [Триллеры, Боевик...
#  title_words          | [спасение]
#  title_words_filtered | [спасение]
#  word_vector          | (200,[2],[1.0])
#  genre_vector         | (83,[0,3,5],[1.0,...
#  item_mean_encoding   | 0.001457725947521...
#  intensity_user       | 0.027575641516660282
#  features             | [754230.0,11520.0...
#  features_minmax      | [0.80078655367760...
#  rawPrediction        | [5.51895446618152...
#  probability          | [0.99600597780049...
#  prediction           | 0.0
#  purchase             | 0.003994022
# -RECORD 13-----------------------------------
#  user_id              | 754230
#  item_id              | 73185
#  title                | стая (8 серий)
#  year                 | 2009.0
#  genres               | Боевики,Наши
#  genres_word          | [Боевики, Наши]
#  title_words          | [стая, (8, серий)]
#  title_words_filtered | [стая, (8, серий)]
#  word_vector          | (200,[32,184,185]...
#  genre_vector         | (83,[5,6],[1.0,1.0])
#  item_mean_encoding   | 0.002201027146001...
#  intensity_user       | 0.027575641516660282
#  features             | [754230.0,73185.0...
#  features_minmax      | [0.80078655367760...
#  rawPrediction        | [5.62765986433344...
#  probability          | [0.99641590900003...
#  prediction           | 0.0
#  purchase             | 0.003584091
# -RECORD 14-----------------------------------
#  user_id              | 754230
#  item_id              | 87168
#  title                | паранормальное яв...
#  year                 | 2010.0
#  genres               | Мистические,Ужасы...
#  genres_word          | [Мистические, Ужа...
#  title_words          | [паранормальное, ...
#  title_words_filtered | [паранормальное, ...
#  word_vector          | (200,[28,82,102,1...
#  genre_vector         | (83,[3,10,30],[1....
#  item_mean_encoding   | 0.005128205128205128
#  intensity_user       | 0.027575641516660282
#  features             | [754230.0,87168.0...
#  features_minmax      | [0.80078655367760...
#  rawPrediction        | [5.42174088922315...
#  probability          | [0.99559999938519...
#  prediction           | 0.0
#  purchase             | 0.0044000004
# -RECORD 15-----------------------------------
#  user_id              | 754230
#  item_id              | 93556
#  title                | артур ньюман проф...
#  year                 | 2012.0
#  genres               | Комедии,Драмы,Зар...
#  genres_word          | [Комедии, Драмы, ...
#  title_words          | [артур, ньюман, п...
#  title_words_filtered | [артур, ньюман, п...
#  word_vector          | (200,[12,16,17,18...
#  genre_vector         | (83,[0,1,2],[1.0,...
#  item_mean_encoding   | 7.457121551081282E-4
#  intensity_user       | 0.027575641516660282
#  features             | [754230.0,93556.0...
#  features_minmax      | [0.80078655367760...
#  rawPrediction        | [5.80573042378332...
#  probability          | [0.99699877925243...
#  prediction           | 0.0
#  purchase             | 0.0030012208
# -RECORD 16-----------------------------------
#  user_id              | 754230
#  item_id              | 95526
#  title                | принцесса и шлюха
#  year                 | 1995.0
#  genres               | Эротика,Зарубежные
#  genres_word          | [Эротика, Зарубеж...
#  title_words          | [принцесса, и, шл...
#  title_words_filtered | [принцесса, шлюха]
#  word_vector          | (200,[87,119],[1....
#  genre_vector         | (83,[0,20],[1.0,1...
#  item_mean_encoding   | 0.0
#  intensity_user       | 0.027575641516660282
#  features             | [754230.0,95526.0...
#  features_minmax      | [0.80078655367760...
#  rawPrediction        | [5.87351524283213...
#  probability          | [0.99719492292176...
#  prediction           | 0.0
#  purchase             | 0.002805077
# -RECORD 17-----------------------------------
#  user_id              | 754230
#  item_id              | 10128
#  title                | план побега
#  year                 | 2013.0
#  genres               | Триллеры,Боевики,...
#  genres_word          | [Триллеры, Боевик...
#  title_words          | [план, побега]
#  title_words_filtered | [план, побега]
#  word_vector          | (200,[55,106],[1....
#  genre_vector         | (83,[0,3,5],[1.0,...
#  item_mean_encoding   | 0.004322766570605188
#  intensity_user       | 0.027575641516660282
#  features             | [754230.0,10128.0...
#  features_minmax      | [0.80078655367760...
#  rawPrediction        | [5.27563546507527...
#  probability          | [0.99491132163235...
#  prediction           | 0.0
#  purchase             | 0.0050886786
# -RECORD 18-----------------------------------
#  user_id              | 754230
#  item_id              | 73421
#  title                | страдающий бессон...
#  year                 | 2013.0
#  genres               | Триллеры,Драмы,За...
#  genres_word          | [Триллеры, Драмы,...
#  title_words          | [страдающий, бесс...
#  title_words_filtered | [страдающий, бесс...
#  word_vector          | (200,[79,124],[1....
#  genre_vector         | (83,[0,1,3],[1.0,...
#  item_mean_encoding   | 0.0
#  intensity_user       | 0.027575641516660282
#  features             | [754230.0,73421.0...
#  features_minmax      | [0.80078655367760...
#  rawPrediction        | [5.81227752972916...
#  probability          | [0.99701830598286...
#  prediction           | 0.0
#  purchase             | 0.002981694
# -RECORD 19-----------------------------------
#  user_id              | 754230
#  item_id              | 74556
#  title                | крик 4
#  year                 | 2011.0
#  genres               | Ужасы,Детективы,З...
#  genres_word          | [Ужасы, Детективы...
#  title_words          | [крик 4]
#  title_words_filtered | [крик 4]
#  word_vector          | (200,[168],[1.0])
#  genre_vector         | (83,[0,10,11],[1....
#  item_mean_encoding   | 0.001519756838905775
#  intensity_user       | 0.027575641516660282
#  features             | [754230.0,74556.0...
#  features_minmax      | [0.80078655367760...
#  rawPrediction        | [5.68839915851223...
#  probability          | [0.99662641212548...
#  prediction           | 0.0
#  purchase             | 0.003373588
# only showing top 20 rows

# %%
prediction = predictions1.select('user_id', 'item_id', 'purchase')

# %%
prediction = prediction.withColumnRenamed('prediction', 'purchase')

# %%
prediction.show(vertical=True)

# %%
prediction.orderBy(["user_id", "item_id"], ascending=[1, 1]).toPandas().to_csv('lab03.csv')

# %%
from pyspark.ml.classification import GBTClassifier
gbt = GBTClassifier(featuresCol='features', labelCol="purchase")

# %%
pipeline_model = gbt.fit(items1)

# %%
predictions = pipeline_model.transform(test)

# %%
predictions.groupby("prediction").count().collect()
# Out:
# [Row(prediction=0.0, count=2156840)]

# %%
from pyspark.ml.evaluation import BinaryClassificationEvaluator
evaluator = BinaryClassificationEvaluator(rawPredictionCol="probability", labelCol="purchase", metricName='areaUnderROC')

# %%
evaluator.evaluate(predictions)

# %%
sc.stop()
